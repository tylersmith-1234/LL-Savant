# %%
from bs4 import BeautifulSoup
import configparser
import requests
import pandas as pd
import pickle
from constants_funcs import get_session, int_or_float_or_str
import json
import numpy as np
import time
with open('constants.json', 'r') as d:
    constants = json.load(d)

# %%
import queue, time, urllib.request
from threading import Thread
def perform_web_requests(things, no_workers, ovr_results: list, error_results: list, func):
    st = time.time()
    class Worker(Thread):
        reqs_done = 0
        def __init__(self, request_queue):
            Thread.__init__(self)
            self.queue = request_queue
            self.results = []

        def run(self):
            while True:
                content = self.queue.get()
                if content == "":
                    break
                try:
                    resp = func(content)
                    self.results.append(resp)
                    ovr_results.append(resp)
                    Worker.reqs_done += 1
                except:
                    print(f'broke on {content}')
                    error_results.append(content)
                if Worker.reqs_done % 1000 == 0:
                    print(f'{Worker.reqs_done} complete')
                self.queue.task_done()


    # Create queue and add addresses
    q = queue.Queue()
    for thing in things:
        q.put(thing)

    # Workers keep working till they receive an empty string
    for _ in range(no_workers):
        q.put("")

    # Create workers and add tot the queue
    workers = []
    for _ in range(no_workers):
        worker = Worker(q)
        worker.start()
        workers.append(worker)
    # Join workers to wait till they finished
    for worker in workers:
        worker.join()

    # Combine results from all workers
    r = []
    for worker in workers:
        r.extend(worker.results)
    print(f'time with {len(r)} requests, {no_workers} workers: {time.time()-st}, errors: {len(error_results)}')
    return r, error_results

# %%
sess = get_session()
sess
# Out:
# using existing login session

# %%
with open('rundles_by_season.json', 'r') as fp:
    all_rundles_by_season = json.load(fp)
all_rundles_by_season
with open('run1/run1.1/player_profile_old_ids.json', 'r') as fp:
    pp = json.load(fp)
with open('player_profiles.json', 'r') as fp:
    player_profiles = json.load(fp)
# for pl in player_profiles.keys():
#     if 'name' in player_profiles[pl].keys(): player_profiles[pl]['username'] = player_profiles[pl]['name']
# with open('player_profiles.json', 'w') as fp:
#     json.dump(player_profiles, fp)
with open('pp_by_username.json', 'r') as fp:
    by_username = json.load(fp)

# %%
def rundle_md_url(rundle: list, season: int, md: int):
    zfilled_md = str(md).zfill(2)
    if season <= 38:
        return f'{constants["LLHEADER"]}/ll{season}/questions/md{zfilled_md}.shtml'
    elif season <= 51:
        url_insert = (rundle[0] if rundle[1] == 'League' else f'{rundle[0]}_{rundle[1]}') + (
            'results' if not (season == 51 and md >= 7) else '')
        return f'{constants["LLHEADER"]}/ll{season}/questions/ll{season}md{zfilled_md}{url_insert}.shtml'
    else:
        base_url = f'{constants["LLHEADER"]}/match.php?{season}&{md}&'
        if rundle[0] == 'Championship':
            return base_url + rundle[0]
        if rundle[2] == 0:
            return base_url + f'{rundle[0]}_{rundle[1]}'
        return base_url + f'{rundle[0]}_{rundle[1]}_Div_{rundle[2]}'
def format_match_result(p1_input, p2_input):
    p1_result = p1_input[0]
    p1_forfeit = p1_input[2] == 'F'
    p2_result = p2_input[0]
    p2_forfeit = p2_input[2] == 'F'
    if p1_forfeit:
        p1_result = 'F'
        p2_result = 'F' if p2_forfeit else 'W'
    elif p2_forfeit:
        p2_result = 'F'
        p1_result = 'W'
    elif p1_result == p2_result:
        p1_result = 'T'
        p2_result = 'T'
    else:
        p1_result = 'W' if int(p1_result) > int(p2_result) else 'L'
        p2_result = 'L' if p1_result == 'W' else 'W'
    return p1_result, p2_result
def build_base_player(id) -> dict:
    # try:
    url = constants['LLHEADER'] + f'/profiles.php?{str(id)}'
    main_data = sess.get(url)
    return build_player_from_soup(main_data)
    # except:
    #     print(f'error on {id}')
    #     return None
def build_player_from_soup(data):
    id = int_or_float_or_str('?'.join(data.url.split('?')[1:]))
    soup = BeautifulSoup(data.text, 'html.parser')
    ret = {'id': id, 'deceased': False}
    a, b = 'This player is inactive.' in soup.text, 'This is not an active player account.' in soup.text
    if a or b:
        ret['current_status'] = 'deactivated'
        ret['username'] = ret['id'] if b else soup.find('div', attrs={'class': 'namediv'}).text.strip()
    else:
        box = soup.find('div', attrs={'class': 'topcont'})
        if '\t\tPassed away' in box.text:
            ret['current_status'] = 'deactivated'
            ret['deceased'] = True
        else:
            ret['current_status'] = box['class'][-1]
        branch_comp = soup.findAll('div', attrs={'class': 'demog_row'})[1]
        ret['branch_id'] = int(branch_comp.find('a')['href'].split('?')[-1])
        ret['branch_name'] = branch_comp.text.strip().split(': ')[1]
        genloc = soup.findAll('div', attrs={'class': 'demog_row'})[0].text.strip().split('\n\n')
        ret['college'] = (soup.find(text='College:').parent.parent.contents[2].strip()
            if soup.find(text='College:') else None)
        ret['gender'] = (soup.find(text='Gender:').parent.parent.text.split(':')[1].strip()
            if soup.find(text='Gender:') else None)
        ret['location'] = (soup.find(text='Location:').parent.parent.text.split(':')[1].strip()
            if soup.find(text='Location:') else None)
        ret['referrer'] = (int(soup.find(text='Referrer:').parent.parent.find('a')['href'].split('?')[-1])
            if soup.find(text='Referrer:') else 0)
        ret['name'] = soup.find('h1', attrs={'class': 'namecss'}).text
        ret['league'] = soup.find('div', attrs={'class': 'leaguelogodiv'}).text.strip()
    return ret
def build_inverse():
    bu = dict()
    for key in player_profiles.keys():
        if 'name' in player_profiles[key].keys: bu[key]['name'] = bu[key]
        else: bu[key]['username'] = bu[key]

# %%
fr = build_base_player(2352)
fr
# Out:
# {'id': 2352,
#  'deceased': False,
#  'current_status': 'topcont',
#  'branch_id': 2352,
#  'branch_name': 'Friedman',
#  'college': 'Univ. of Cincinnati, Miami Univ.',
#  'gender': 'Male',
#  'location': 'Cleveland, Ohio',
#  'referrer': 21064,
#  'name': 'Friedman',
#  'league': 'Central'}

# %%
# helper functions: take in soup, return list of formatted matches.
def pre_38(soup, rundle, season, md):
    header_text = 'Rundle ' + (rundle[0] if rundle[1] == 'League' or season <= 33 else rundle[0] + ' ' + rundle[1])
    matches = soup.find(text=header_text).parent.next_element.next_element.find_all('div', {'class': 'sbGame'})
    # print(matches)
    match_participation = []
    matches_history = []
    player_answer_history = []
    for match in matches:
        match_id = match['onclick'].split('/')[-1].split('.')[0]
        matches_history.append([match_id, *rundle, season, md])
        current_match_url = match['onclick'].split("'")[1]
        try:
            match_soup = BeautifulSoup(sess.get(constants['LLHEADER'] + current_match_url).text, 'html.parser')
            rows = match_soup.find('td').find('center').find('tr').find('table').find_all('tr')
            match_results = [None, None]
            for idx, player in enumerate(rows[1:3]):
                tds = player.find_all('td')
                player_id = tds[0].find('a')['href'].split('/')[-1].split('.')[0]
                tot_pts, tot_correct = list(map(lambda i: int_or_float_or_str(i[0]), tds[7].text.split('(')))
                fft = tot_correct == 'F'
                q_correct = [None]*6 if tot_correct == 'F' else list(
                    map(lambda td: td.find('div')['class'][0] == 'green', tds[1:7]))
                def_given = list(map(lambda td: int('1' if td.text == 'w' and season == 36 else td.text), tds[1:7]))
                if sum(def_given) == 0: # then you were forfeited against.
                    def_given = [None]*6
                match_results[idx] = {'id': player_id, 'fft': fft, 'tot_pts': tot_pts}
                for qnum in range(6):
                    player_answer_history.append([
                        match_id, *rundle, season, md, qnum+1,
                        player_id, q_correct[qnum], def_given[qnum]
                    ])
            p1_res, p2_res = '', ''
            if match_results[0]['fft']:
                p1_res = 'F'
                p2_res = 'F' if match_results[1]['fft'] else 'W'
            elif match_results[1]['fft']:
                p1_res, p2_res = 'W', 'F'
            elif match_results[0]['tot_pts'] == match_results[1]['tot_pts']:
                p1_res, p2_res = 'T', 'T'
            elif match_results[0]['tot_pts'] > match_results[1]['tot_pts']:
                p1_res, p2_res = 'W', 'L'
            else:
                p1_res, p2_res = 'L', 'W'
            match_participation.append([
                match_id, season, md, *rundle,
                match_results[0]['id'], p1_res
            ])
            match_participation.append([
                match_id, season, md, *rundle,
                match_results[1]['id'], p2_res
            ])
        except:
            print(f'failed on LL{season}-{md} match {match_id}')
        # break
    # print(matches_history, match_participation, player_answer_history)
    return matches_history, match_participation, player_answer_history
# for season in range(30, 39):
def main_pre_38(content):
    rundle, season, md = content['rundle'], content['season'], content['md']
    url = rundle_md_url(rundle, season, md)
    gamepage = sess.get(url)
    html_text = gamepage.text
    soup = BeautifulSoup(html_text, 'html.parser')
    ret = dict()
    ret['matches_history'], ret['match_participation'], ret['player_answer_history'] = pre_38(soup, rundle, season, md)
    return ret
main_pre_38({'rundle': ['R', 'League', 0], 'season': 37, 'md': 1})
# Out:
# failed on LL37-1 match 38539601
# {'matches_history': [['38539601', 'R', 'League', 0, 37, 1],
#   ['39039901', 'R', 'League', 0, 37, 1],
#   ['39139201', 'R', 'League', 0, 37, 1],
#   ['38738801', 'R', 'League', 0, 37, 1],
#   ['39839301', 'R', 'League', 0, 37, 1],
#   ['38638401', 'R', 'League', 0, 37, 1],
#   ['38939501', 'R', 'League', 0, 37, 1],
#   ['39739401', 'R', 'League', 0, 37, 1]],
#  'match_participation': [['39039901',
#    37,
#    1,
#    'R',
#    'League',
#    0,
#    'mendelsohnj',
#    'L'],
#   ['39039901', 37, 1, 'R', 'League', 0, 'lefskyd', 'W'],
#   ['39139201', 37, 1, 'R', 'League', 0, 'murrells', 'L'],
#   ['39139201', 37, 1, 'R', 'League', 0, 'pliskag', 'W'],
#   ['38738801', 37, 1, 'R', 'League', 0, 'huntt', 'L'],
#   ['38738801', 37, 1, 'R', 'League', 0, 'leer', 'W'],
#   ['39839301', 37, 1, 'R', 'League', 0, 'burlinm2', 'W'],
#   ['39839301', 37, 1, 'R', 'League', 0, 'pontiusk', 'L'],
#   ['38638401', 37, 1, 'R', 'League', 0, 'glassmand', 'W'],
#   ['38638401', 37, 1, 'R', 'League', 0, 'chengc', 'L'],
#   ['38939501', 37, 1, 'R', 'League', 0, 'lipmana', 'W'],
#   ['38939501', 37, 1, 'R', 'League', 0, 'santillanesl', 'L'],
#   ['39739401', 37, 1, 'R', 'League', 0, 'wolfej', 'W'],
#   ['39739401', 37, 1, 'R', 'League', 0, 'roselundt', 'L']],
#  'player_answer_history': [['39039901',
#    'R',
#    'League',
#    0,
#    37,
#    1,
#    1,
#    'mendelsohnj',
#    True,
#    0],
#   ['39039901', 'R', 'League', 0, 37, 1, 2, 'mendelsohnj', True, 1],
#   ['39039901', 'R', 'League', 0, 37, 1, 3, 'mendelsohnj', False, 3],
#   ['39039901', 'R', 'League', 0, 37, 1, 4, 'mendelsohnj', True, 1],
#   ['39039901', 'R', 'League', 0, 37, 1, 5, 'mendelsohnj', False, 2],
#   ['39039901', 'R', 'League', 0, 37, 1, 6, 'mendelsohnj', False, 2],
#   ['39039901', 'R', 'League', 0, 37, 1, 1, 'lefskyd', True, 2],
#   ['39039901', 'R', 'League', 0, 37, 1, 2, 'lefskyd', False, 1],
#   ['39039901', 'R', 'League', 0, 37, 1, 3, 'lefskyd', False, 2],
#   ['39039901', 'R', 'League', 0, 37, 1, 4, 'lefskyd', True, 0],
#   ['39039901', 'R', 'League', 0, 37, 1, 5, 'lefskyd', True, 1],
#   ['39039901', 'R', 'League', 0, 37, 1, 6, 'lefskyd', False, 3],
#   ['39139201', 'R', 'League', 0, 37, 1, 1, 'murrells', False, 1],
#   ['39139201', 'R', 'League', 0, 37, 1, 2, 'murrells', False, 3],
#   ['39139201', 'R', 'League', 0, 37, 1, 3, 'murrells', False, 2],
#   ['39139201', 'R', 'League', 0, 37, 1, 4, 'murrells', False, 0],
#   ['39139201', 'R', 'League', 0, 37, 1, 5, 'murrells', False, 1],
#   ['39139201', 'R', 'League', 0, 37, 1, 6, 'murrells', False, 2],
#   ['39139201', 'R', 'League', 0, 37, 1, 1, 'pliskag', True, 1],
#   ['39139201', 'R', 'League', 0, 37, 1, 2, 'pliskag', False, 0],
#   ['39139201', 'R', 'League', 0, 37, 1, 3, 'pliskag', False, 2],
#   ['39139201', 'R', 'League', 0, 37, 1, 4, 'pliskag', False, 2],
#   ['39139201', 'R', 'League', 0, 37, 1, 5, 'pliskag', True, 1],
#   ['39139201', 'R', 'League', 0, 37, 1, 6, 'pliskag', True, 3],
#   ['38738801', 'R', 'League', 0, 37, 1, 1, 'huntt', False, 1],
#   ['38738801', 'R', 'League', 0, 37, 1, 2, 'huntt', False, 3],
#   ['38738801', 'R', 'League', 0, 37, 1, 3, 'huntt', False, 1],
#   ['38738801', 'R', 'League', 0, 37, 1, 4, 'huntt', True, 2],
#   ['38738801', 'R', 'League', 0, 37, 1, 5, 'huntt', False, 2],
#   ['38738801', 'R', 'League', 0, 37, 1, 6, 'huntt', False, 0],
#   ['38738801', 'R', 'League', 0, 37, 1, 1, 'leer', False, 1],
#   ['38738801', 'R', 'League', 0, 37, 1, 2, 'leer', False, 0],
#   ['38738801', 'R', 'League', 0, 37, 1, 3, 'leer', False, 2],
#   ['38738801', 'R', 'League', 0, 37, 1, 4, 'leer', True, 1],
#   ['38738801', 'R', 'League', 0, 37, 1, 5, 'leer', False, 3],
#   ['38738801', 'R', 'League', 0, 37, 1, 6, 'leer', True, 2],
#   ['39839301', 'R', 'League', 0, 37, 1, 1, 'burlinm2', True, 1],
#   ['39839301', 'R', 'League', 0, 37, 1, 2, 'burlinm2', True, 2],
#   ['39839301', 'R', 'League', 0, 37, 1, 3, 'burlinm2', False, 3],
#   ['39839301', 'R', 'League', 0, 37, 1, 4, 'burlinm2', True, 0],
#   ['39839301', 'R', 'League', 0, 37, 1, 5, 'burlinm2', True, 1],
#   ['39839301', 'R', 'League', 0, 37, 1, 6, 'burlinm2', True, 2],
#   ['39839301', 'R', 'League', 0, 37, 1, 1, 'pontiusk', False, 3],
#   ['39839301', 'R', 'League', 0, 37, 1, 2, 'pontiusk', True, 2],
#   ['39839301', 'R', 'League', 0, 37, 1, 3, 'pontiusk', False, 2],
#   ['39839301', 'R', 'League', 0, 37, 1, 4, 'pontiusk', True, 1],
#   ['39839301', 'R', 'League', 0, 37, 1, 5, 'pontiusk', False, 1],
#   ['39839301', 'R', 'League', 0, 37, 1, 6, 'pontiusk', False, 0],
#   ['38638401', 'R', 'League', 0, 37, 1, 1, 'glassmand', True, 0],
#   ['38638401', 'R', 'League', 0, 37, 1, 2, 'glassmand', False, 1],
#   ['38638401', 'R', 'League', 0, 37, 1, 3, 'glassmand', False, 2],
#   ['38638401', 'R', 'League', 0, 37, 1, 4, 'glassmand', True, 3],
#   ['38638401', 'R', 'League', 0, 37, 1, 5, 'glassmand', True, 1],
#   ['38638401', 'R', 'League', 0, 37, 1, 6, 'glassmand', True, 2],
#   ['38638401', 'R', 'League', 0, 37, 1, 1, 'chengc', True, 0],
#   ['38638401', 'R', 'League', 0, 37, 1, 2, 'chengc', True, 3],
#   ['38638401', 'R', 'League', 0, 37, 1, 3, 'chengc', False, 1],
#   ['38638401', 'R', 'League', 0, 37, 1, 4, 'chengc', False, 2],
#   ['38638401', 'R', 'League', 0, 37, 1, 5, 'chengc', True, 1],
#   ['38638401', 'R', 'League', 0, 37, 1, 6, 'chengc', False, 2],
#   ['38939501', 'R', 'League', 0, 37, 1, 1, 'lipmana', True, 0],
#   ['38939501', 'R', 'League', 0, 37, 1, 2, 'lipmana', True, 1],
#   ['38939501', 'R', 'League', 0, 37, 1, 3, 'lipmana', False, 2],
#   ['38939501', 'R', 'League', 0, 37, 1, 4, 'lipmana', True, 1],
#   ['38939501', 'R', 'League', 0, 37, 1, 5, 'lipmana', True, 3],
#   ['38939501', 'R', 'League', 0, 37, 1, 6, 'lipmana', True, 2],
#   ['38939501', 'R', 'League', 0, 37, 1, 1, 'santillanesl', True, 1],
#   ['38939501', 'R', 'League', 0, 37, 1, 2, 'santillanesl', False, 2],
#   ['38939501', 'R', 'League', 0, 37, 1, 3, 'santillanesl', False, 0],
#   ['38939501', 'R', 'League', 0, 37, 1, 4, 'santillanesl', False, 3],
#   ['38939501', 'R', 'League', 0, 37, 1, 5, 'santillanesl', False, 2],
#   ['38939501', 'R', 'League', 0, 37, 1, 6, 'santillanesl', True, 1],
#   ['39739401', 'R', 'League', 0, 37, 1, 1, 'wolfej', True, 0],
#   ['39739401', 'R', 'League', 0, 37, 1, 2, 'wolfej', True, 2],
#   ['39739401', 'R', 'League', 0, 37, 1, 3, 'wolfej', False, 3],
#   ['39739401', 'R', 'League', 0, 37, 1, 4, 'wolfej', True, 1],
#   ['39739401', 'R', 'League', 0, 37, 1, 5, 'wolfej', False, 1],
#   ['39739401', 'R', 'League', 0, 37, 1, 6, 'wolfej', True, 2],
#   ['39739401', 'R', 'League', 0, 37, 1, 1, 'roselundt', True, 1],
#   ['39739401', 'R', 'League', 0, 37, 1, 2, 'roselundt', False, 2],
#   ['39739401', 'R', 'League', 0, 37, 1, 3, 'roselundt', False, 3],
#   ['39739401', 'R', 'League', 0, 37, 1, 4, 'roselundt', True, 1],
#   ['39739401', 'R', 'League', 0, 37, 1, 5, 'roselundt', True, 2],
#   ['39739401', 'R', 'League', 0, 37, 1, 6, 'roselundt', True, 0]]}

# %%
for season in [37]:
    season_prep_data = []
    cur_rundles = all_rundles_by_season[str(season)]['rundles']
    ovr_results, err_results = [], []
    for md in range(1, 21):
        for rundle in cur_rundles:
            # prep_data.append({'rundle': rundle, 'season': season, 'md': md})
            season_prep_data.append({'rundle': rundle, 'season': season, 'md': md})
    try:
        tot, err = perform_web_requests(season_prep_data, 8, ovr_results, err_results, main_pre_38)
        with open(f'./FULL_DATA/LL{season}/results.json', 'w') as fp:
            json.dump(tot, fp)
    except:
        print(f'season {season} failed')
# Out:
# failed on LL37-1 match 38539601
# failed on LL37-1 match 37935001
# failed on LL37-6 match 37726706
# failed on LL37-6 match 39939206
# failed on LL37-6 match 39839706
# failed on LL37-7 match 37734007
# failed on LL37-6 match 37904506
# failed on LL37-6 match 36909306
# failed on LL37-6 match 38233606
# failed on LL37-7 match 37408307
# failed on LL37-7 match 39938707
# time with 140 requests, 8 workers: 68.70735001564026, errors: 0

# %%
def from_39_to_51(soup, rundle, season, md):
    match_urls = list(map(lambda tr: tr.contents[-1].find('a')['href'], soup.find('table', {'class': 'tblResults'}).find_all('tr')))
    match_participation = []
    matches_history = []
    player_answer_history = []
    for url in match_urls:
        match_id = url.split('/')[-1].split('.')[0]
        matches_history.append([match_id, *rundle, season, md])
        # match_soup = BeautifulSoup(sess.get(constants['LLHEADER'] + url).text, 'html.parser')
        # rows = match_soup.find('td').find('center').find('tr').find('table').find_all('tr')
        try:
            match_soup = BeautifulSoup(sess.get(constants['LLHEADER'] + url).text, 'html.parser')
            rows = match_soup.find('td').find('center').find('tr').find('table').find_all('tr') 
            match_results = [None, None]
            for idx, player in enumerate(rows[1:3]):
                tds = player.find_all('td')
                player_id = tds[0].find('a')['href'].split('/')[-1].split('.')[0]
                tot_pts, tot_correct = list(map(lambda i: int_or_float_or_str(i[0]), tds[7].text.split('(')))
                fft = tot_correct == 'F'
                q_correct = [None]*6 if tot_correct == 'F' else list(
                    map(lambda td: 'Green' in td['class'][0] or
                    'green' in td.find('div')['class'][0], tds[1:7]))
                def_given = list(map(lambda td: int(
                    td.text if str(td.text).isnumeric() else 0), tds[1:7]))
                if sum(def_given) == 0: # then you were forfeited against.
                    def_given = [None]*6
                match_results[idx] = {'id': player_id, 'fft': fft, 'tot_pts': tot_pts}
                for qnum in range(6):
                    player_answer_history.append([
                        match_id, *rundle, season, md, qnum+1,
                        player_id, q_correct[qnum], def_given[qnum]
                    ])
            p1_res, p2_res = '', ''
            if match_results[0]['fft']:
                p1_res = 'F'
                p2_res = 'F' if match_results[1]['fft'] else 'W'
            elif match_results[1]['fft']:
                p1_res, p2_res = 'W', 'F'
            elif match_results[0]['tot_pts'] == match_results[1]['tot_pts']:
                p1_res, p2_res = 'T', 'T'
            elif match_results[0]['tot_pts'] > match_results[1]['tot_pts']:
                p1_res, p2_res = 'W', 'L'
            else:
                p1_res, p2_res = 'L', 'W'
            match_participation.append([
                match_id, season, md, *rundle,
                match_results[0]['id'], p1_res
            ])
            match_participation.append([
                match_id, season, md, *rundle,
                match_results[1]['id'], p2_res
            ])
        except:
            print(f'failed on LL{season}-{md} match {match_id}')
        # break
    # print(matches_history, match_participation, player_answer_history)
    return matches_history, match_participation, player_answer_history

def main_39_51(content):
    rundle, season, md = content['rundle'], content['season'], content['md']
    url = rundle_md_url(rundle, season, md)
    gamepage = sess.get(url)
    html_text = gamepage.text
    soup = BeautifulSoup(html_text, 'html.parser')
    ret = dict()
    ret['matches_history'], ret['match_participation'], ret['player_answer_history'] = from_39_to_51(soup, rundle, season, md)
    return ret
main_39_51({'rundle': ['R', 'League', 0], 'season': 40, 'md': 1})
# Out:
# {'matches_history': [['44847201', 'R', 'League', 0, 40, 1],
#   ['46045701', 'R', 'League', 0, 40, 1],
#   ['46847801', 'R', 'League', 0, 40, 1],
#   ['46945901', 'R', 'League', 0, 40, 1],
#   ['46147501', 'R', 'League', 0, 40, 1],
#   ['45646201', 'R', 'League', 0, 40, 1],
#   ['47646601', 'R', 'League', 0, 40, 1],
#   ['47146701', 'R', 'League', 0, 40, 1],
#   ['47045401', 'R', 'League', 0, 40, 1]],
#  'match_participation': [['44847201', 40, 1, 'R', 'League', 0, 'berlinb', 'L'],
#   ['44847201', 40, 1, 'R', 'League', 0, 'sandozm', 'W'],
#   ['46045701', 40, 1, 'R', 'League', 0, 'gwynne', 'L'],
#   ['46045701', 40, 1, 'R', 'League', 0, 'dobsont', 'W'],
#   ['46847801', 40, 1, 'R', 'League', 0, 'murphym2', 'W'],
#   ['46847801', 40, 1, 'R', 'League', 0, 'weitzmanm', 'F'],
#   ['46945901', 40, 1, 'R', 'League', 0, 'naliboffl', 'L'],
#   ['46945901', 40, 1, 'R', 'League', 0, 'fogertya', 'W'],
#   ['46147501', 40, 1, 'R', 'League', 0, 'jastrzebskis', 'W'],
#   ['46147501', 40, 1, 'R', 'League', 0, 'swaminathann', 'L'],
#   ['45646201', 40, 1, 'R', 'League', 0, 'colemanr', 'W'],
#   ['45646201', 40, 1, 'R', 'League', 0, 'kellya', 'L'],
#   ['47646601', 40, 1, 'R', 'League', 0, 'walshk', 'L'],
#   ['47646601', 40, 1, 'R', 'League', 0, 'millars', 'W'],
#   ['47146701', 40, 1, 'R', 'League', 0, 'robertst', 'W'],
#   ['47146701', 40, 1, 'R', 'League', 0, 'mullerj', 'F'],
#   ['47045401', 40, 1, 'R', 'League', 0, 'philiposet', 'W'],
#   ['47045401', 40, 1, 'R', 'League', 0, 'careyk', 'L']],
#  'player_answer_history': [['44847201',
#    'R',
#    'League',
#    0,
#    40,
#    1,
#    1,
#    'berlinb',
#    False,
#    1],
#   ['44847201', 'R', 'League', 0, 40, 1, 2, 'berlinb', False, 1],
#   ['44847201', 'R', 'League', 0, 40, 1, 3, 'berlinb', False, 2],
#   ['44847201', 'R', 'League', 0, 40, 1, 4, 'berlinb', False, 3],
#   ['44847201', 'R', 'League', 0, 40, 1, 5, 'berlinb', False, 0],
#   ['44847201', 'R', 'League', 0, 40, 1, 6, 'berlinb', False, 2],
#   ['44847201', 'R', 'League', 0, 40, 1, 1, 'sandozm', True, 1],
#   ['44847201', 'R', 'League', 0, 40, 1, 2, 'sandozm', False, 2],
#   ['44847201', 'R', 'League', 0, 40, 1, 3, 'sandozm', False, 0],
#   ['44847201', 'R', 'League', 0, 40, 1, 4, 'sandozm', False, 3],
#   ['44847201', 'R', 'League', 0, 40, 1, 5, 'sandozm', False, 1],
#   ['44847201', 'R', 'League', 0, 40, 1, 6, 'sandozm', False, 2],
#   ['46045701', 'R', 'League', 0, 40, 1, 1, 'gwynne', True, 3],
#   ['46045701', 'R', 'League', 0, 40, 1, 2, 'gwynne', True, 1],
#   ['46045701', 'R', 'League', 0, 40, 1, 3, 'gwynne', True, 2],
#   ['46045701', 'R', 'League', 0, 40, 1, 4, 'gwynne', True, 0],
#   ['46045701', 'R', 'League', 0, 40, 1, 5, 'gwynne', False, 2],
#   ['46045701', 'R', 'League', 0, 40, 1, 6, 'gwynne', False, 1],
#   ['46045701', 'R', 'League', 0, 40, 1, 1, 'dobsont', True, 0],
#   ['46045701', 'R', 'League', 0, 40, 1, 2, 'dobsont', True, 2],
#   ['46045701', 'R', 'League', 0, 40, 1, 3, 'dobsont', True, 2],
#   ['46045701', 'R', 'League', 0, 40, 1, 4, 'dobsont', True, 1],
#   ['46045701', 'R', 'League', 0, 40, 1, 5, 'dobsont', True, 1],
#   ['46045701', 'R', 'League', 0, 40, 1, 6, 'dobsont', True, 3],
#   ['46847801', 'R', 'League', 0, 40, 1, 1, 'murphym2', True, None],
#   ['46847801', 'R', 'League', 0, 40, 1, 2, 'murphym2', False, None],
#   ['46847801', 'R', 'League', 0, 40, 1, 3, 'murphym2', True, None],
#   ['46847801', 'R', 'League', 0, 40, 1, 4, 'murphym2', True, None],
#   ['46847801', 'R', 'League', 0, 40, 1, 5, 'murphym2', False, None],
#   ['46847801', 'R', 'League', 0, 40, 1, 6, 'murphym2', False, None],
#   ['46847801', 'R', 'League', 0, 40, 1, 1, 'weitzmanm', None, 1],
#   ['46847801', 'R', 'League', 0, 40, 1, 2, 'weitzmanm', None, 2],
#   ['46847801', 'R', 'League', 0, 40, 1, 3, 'weitzmanm', None, 0],
#   ['46847801', 'R', 'League', 0, 40, 1, 4, 'weitzmanm', None, 1],
#   ['46847801', 'R', 'League', 0, 40, 1, 5, 'weitzmanm', None, 3],
#   ['46847801', 'R', 'League', 0, 40, 1, 6, 'weitzmanm', None, 2],
#   ['46945901', 'R', 'League', 0, 40, 1, 1, 'naliboffl', False, 3],
#   ['46945901', 'R', 'League', 0, 40, 1, 2, 'naliboffl', False, 2],
#   ['46945901', 'R', 'League', 0, 40, 1, 3, 'naliboffl', False, 0],
#   ['46945901', 'R', 'League', 0, 40, 1, 4, 'naliboffl', True, 2],
#   ['46945901', 'R', 'League', 0, 40, 1, 5, 'naliboffl', False, 1],
#   ['46945901', 'R', 'League', 0, 40, 1, 6, 'naliboffl', False, 1],
#   ['46945901', 'R', 'League', 0, 40, 1, 1, 'fogertya', True, 1],
#   ['46945901', 'R', 'League', 0, 40, 1, 2, 'fogertya', True, 2],
#   ['46945901', 'R', 'League', 0, 40, 1, 3, 'fogertya', False, 2],
#   ['46945901', 'R', 'League', 0, 40, 1, 4, 'fogertya', False, 0],
#   ['46945901', 'R', 'League', 0, 40, 1, 5, 'fogertya', False, 1],
#   ['46945901', 'R', 'League', 0, 40, 1, 6, 'fogertya', False, 3],
#   ['46147501', 'R', 'League', 0, 40, 1, 1, 'jastrzebskis', True, 2],
#   ['46147501', 'R', 'League', 0, 40, 1, 2, 'jastrzebskis', True, 2],
#   ['46147501', 'R', 'League', 0, 40, 1, 3, 'jastrzebskis', False, 1],
#   ['46147501', 'R', 'League', 0, 40, 1, 4, 'jastrzebskis', True, 3],
#   ['46147501', 'R', 'League', 0, 40, 1, 5, 'jastrzebskis', False, 1],
#   ['46147501', 'R', 'League', 0, 40, 1, 6, 'jastrzebskis', False, 0],
#   ['46147501', 'R', 'League', 0, 40, 1, 1, 'swaminathann', True, 1],
#   ['46147501', 'R', 'League', 0, 40, 1, 2, 'swaminathann', True, 0],
#   ['46147501', 'R', 'League', 0, 40, 1, 3, 'swaminathann', False, 2],
#   ['46147501', 'R', 'League', 0, 40, 1, 4, 'swaminathann', True, 1],
#   ['46147501', 'R', 'League', 0, 40, 1, 5, 'swaminathann', False, 2],
#   ['46147501', 'R', 'League', 0, 40, 1, 6, 'swaminathann', False, 3],
#   ['45646201', 'R', 'League', 0, 40, 1, 1, 'colemanr', True, 2],
#   ['45646201', 'R', 'League', 0, 40, 1, 2, 'colemanr', False, 1],
#   ['45646201', 'R', 'League', 0, 40, 1, 3, 'colemanr', False, 0],
#   ['45646201', 'R', 'League', 0, 40, 1, 4, 'colemanr', False, 2],
#   ['45646201', 'R', 'League', 0, 40, 1, 5, 'colemanr', False, 3],
#   ['45646201', 'R', 'League', 0, 40, 1, 6, 'colemanr', False, 1],
#   ['45646201', 'R', 'League', 0, 40, 1, 1, 'kellya', True, 0],
#   ['45646201', 'R', 'League', 0, 40, 1, 2, 'kellya', True, 1],
#   ['45646201', 'R', 'League', 0, 40, 1, 3, 'kellya', False, 1],
#   ['45646201', 'R', 'League', 0, 40, 1, 4, 'kellya', False, 3],
#   ['45646201', 'R', 'League', 0, 40, 1, 5, 'kellya', False, 2],
#   ['45646201', 'R', 'League', 0, 40, 1, 6, 'kellya', False, 2],
#   ['47646601', 'R', 'League', 0, 40, 1, 1, 'walshk', True, 2],
#   ['47646601', 'R', 'League', 0, 40, 1, 2, 'walshk', False, 2],
#   ['47646601', 'R', 'League', 0, 40, 1, 3, 'walshk', False, 1],
#   ['47646601', 'R', 'League', 0, 40, 1, 4, 'walshk', True, 0],
#   ['47646601', 'R', 'League', 0, 40, 1, 5, 'walshk', False, 1],
#   ['47646601', 'R', 'League', 0, 40, 1, 6, 'walshk', False, 3],
#   ['47646601', 'R', 'League', 0, 40, 1, 1, 'millars', True, 2],
#   ['47646601', 'R', 'League', 0, 40, 1, 2, 'millars', False, 1],
#   ['47646601', 'R', 'League', 0, 40, 1, 3, 'millars', True, 1],
#   ['47646601', 'R', 'League', 0, 40, 1, 4, 'millars', True, 2],
#   ['47646601', 'R', 'League', 0, 40, 1, 5, 'millars', False, 0],
#   ['47646601', 'R', 'League', 0, 40, 1, 6, 'millars', False, 3],
#   ['47146701', 'R', 'League', 0, 40, 1, 1, 'robertst', True, None],
#   ['47146701', 'R', 'League', 0, 40, 1, 2, 'robertst', False, None],
#   ['47146701', 'R', 'League', 0, 40, 1, 3, 'robertst', False, None],
#   ['47146701', 'R', 'League', 0, 40, 1, 4, 'robertst', True, None],
#   ['47146701', 'R', 'League', 0, 40, 1, 5, 'robertst', False, None],
#   ['47146701', 'R', 'League', 0, 40, 1, 6, 'robertst', False, None],
#   ['47146701', 'R', 'League', 0, 40, 1, 1, 'mullerj', None, 0],
#   ['47146701', 'R', 'League', 0, 40, 1, 2, 'mullerj', None, 2],
#   ['47146701', 'R', 'League', 0, 40, 1, 3, 'mullerj', None, 1],
#   ['47146701', 'R', 'League', 0, 40, 1, 4, 'mullerj', None, 3],
#   ['47146701', 'R', 'League', 0, 40, 1, 5, 'mullerj', None, 2],
#   ['47146701', 'R', 'League', 0, 40, 1, 6, 'mullerj', None, 1],
#   ['47045401', 'R', 'League', 0, 40, 1, 1, 'philiposet', True, 3],
#   ['47045401', 'R', 'League', 0, 40, 1, 2, 'philiposet', True, 2],
#   ['47045401', 'R', 'League', 0, 40, 1, 3, 'philiposet', False, 0],
#   ['47045401', 'R', 'League', 0, 40, 1, 4, 'philiposet', True, 2],
#   ['47045401', 'R', 'League', 0, 40, 1, 5, 'philiposet', True, 1],
#   ['47045401', 'R', 'League', 0, 40, 1, 6, 'philiposet', False, 1],
#   ['47045401', 'R', 'League', 0, 40, 1, 1, 'careyk', True, 1],
#   ['47045401', 'R', 'League', 0, 40, 1, 2, 'careyk', True, 2],
#   ['47045401', 'R', 'League', 0, 40, 1, 3, 'careyk', False, 1],
#   ['47045401', 'R', 'League', 0, 40, 1, 4, 'careyk', False, 2],
#   ['47045401', 'R', 'League', 0, 40, 1, 5, 'careyk', False, 3],
#   ['47045401', 'R', 'League', 0, 40, 1, 6, 'careyk', False, 0]]}

# %%
for season in range(49, 52):
    season_prep_data = []
    cur_rundles = all_rundles_by_season[str(season)]['rundles']
    ovr_results = []
    for md in range(1, 26 if season < 51 else 7):
        for rundle in cur_rundles:
            # prep_data.append({'rundle': rundle, 'season': season, 'md': md})
            season_prep_data.append({'rundle': rundle, 'season': season, 'md': md})
    try:
        tot = perform_web_requests(season_prep_data, 8, ovr_results, main_39_51)
        with open(f'./FULL_DATA/LL{season}/results.json', 'w') as fp:
            json.dump(tot, fp)
    except:
        print(f'season {season} failed')
# Out:
# time with 525 requests, 8 workers: 603.8545551300049
# time with 525 requests, 8 workers: 715.4193091392517
# time with 168 requests, 8 workers: 203.6491141319275

# %%
def special_51(soup: BeautifulSoup, rundle, season, md):
    matches = soup.find('table', {'class': 'tblResults2'})
    to_take = len(matches)*2
    full_questions = soup.find('table', {'class': 'sortable'}).find('tbody').find_all('tr')[:to_take]
    match_participation = []
    matches_history = []
    player_answer_history = []
    temp_players = dict()
    for player_row in full_questions:
        tds = player_row.find_all('td')
        q_tds = tds[:6]
        player_username = '_'.join(tds[7].text.strip().split())
        fft = 'Black' in q_tds[0]['style']
        q_correct = [None]*6 if fft else list(map(lambda q: 'Green' in q['style'], q_tds))
        def_given = list(map(lambda q:
            int(q.text) if q.text.isnumeric() else None, q_tds))
        tot_correct, tot_pts = 'F', 0
        if not fft:
            tot_correct = sum(q_correct)
            if def_given[0] is not None: tot_pts = sum(np.multiply(q_correct, def_given))
            else: tot_pts = round(1.5*tot_correct)
        temp_players[player_username] = {'id': player_username,
            'fft': fft, 'q_correct': q_correct, 'def_given': def_given,
            'tot_correct': tot_correct, 'tot_pts': tot_pts}

    for match in matches:
        p1_id, p2_id = '_'.join(
            match.contents[1].text.strip().split()), '_'.join(
            match.contents[3].text.strip().split())
        match_id = match.contents[2].find('a')['href'].split('/')[-1].split('.')[0]
        matches_history.append([match_id, *rundle, season, md])
        p1, p2 = temp_players[p1_id], temp_players[p2_id]
        if p1['fft']:
            p1['result'] = 'F'
            p2['result'] = 'F' if p2['fft'] else 'W'
        elif p2['fft']: p1['result'], p2['result'] = 'W', 'F'
        elif p1['tot_pts'] == p2['tot_pts']: p1['result'], p2['result'] = 'T', 'T'
        elif p1['tot_pts'] > p2['tot_pts']: p1['result'], p2['result'] = 'W', 'L'
        else: p1['result'], p2['result'] = 'L', 'W'
        match_participation.append([
            match_id, season, md, *rundle,
            p1['id'], p1['result']
        ])
        match_participation.append([
            match_id, season, md, *rundle,
            p2['id'], p2['result']
        ])
        for qnum in range(6):
            player_answer_history.append([
                match_id, *rundle, season, md, qnum+1,
                p1['id'], p1['q_correct'][qnum], p1['def_given'][qnum]
            ])
            player_answer_history.append([
                match_id, *rundle, season, md, qnum+1,
                p2['id'], p2['q_correct'][qnum], p2['def_given'][qnum]
            ])
    return matches_history, match_participation, player_answer_history

def main_special_51(content):
    rundle, season, md = content['rundle'], content['season'], content['md']
    url = rundle_md_url(rundle, season, md)
    gamepage = sess.get(url)
    html_text = gamepage.text
    soup = BeautifulSoup(html_text, 'html.parser')
    ret = dict()
    ret['matches_history'], ret['match_participation'], ret['player_answer_history'] = special_51(soup, rundle, season, md)
    return ret
# main_special_51({'rundle': ['E', 'Northeast', 0], 'season': 51, 'md': 7})

# %%
# remainder of season 51
with open('./FULL_DATA/LL51/results.json', 'r') as fp:
    cur_51 = json.load(fp)
print(len(cur_51))
season_prep_data = []
cur_rundles = all_rundles_by_season['51']['rundles']
ovr_results = []
for md in range(7, 26):
    for rundle in cur_rundles:
        # prep_data.append({'rundle': rundle, 'season': season, 'md': md})
        season_prep_data.append({'rundle': rundle, 'season': season, 'md': md})
try:
    tot = perform_web_requests(season_prep_data, 8, ovr_results, main_special_51)
    cur_51.extend(tot)
    with open('./FULL_DATA/LL51/results.json', 'w') as fp:
        json.dump(cur_51, fp)
except:
    print('season 51 failed')
# Out:
# 168
# broke on {'rundle': ['C', 'Coastal', 0], 'season': 51, 'md': 17}
# time with 531 requests, 8 workers: 32.81769013404846

# %%
with open('alt_ids.json', 'r') as rp:
    change_id = json.load(rp)
with open('player_profiles.json', 'r') as fp:
    player_profiles = json.load(fp)
def post_52(soup: BeautifulSoup, rundle, season, md):
    global player_profiles
    matches = soup.find('table', {'class': 'gamelinetbl'}).find_all('tr')
    is_jacobs_s = 'Jacobs S.' in soup.find('table', {'class': 'gamelinetbl'}).text
    missing_one_match = (
        season == 75 and rundle[0] == 'E' and rundle[1] == 'Central' and rundle[2] == 2 and (md < 10 or md > 23)) or (
        season == 76 and rundle[0] == 'C' and rundle[1] == 'Citadel' and rundle[2] == 2) or (
        season == 75 and rundle[0] == 'D' and rundle[1] == 'Maelstrom' and rundle[2] == 1 and md in [8, 9, 10, 24, 25]
        )
    to_take = (len(matches) + int(missing_one_match))*2 - int(is_jacobs_s)
    if to_take > 0 and season != 73 and md != 23:
        full_questions = soup.find('table', {'class': 'sortable'}).find('tbody').find_all('tr')[:to_take]
    else: full_questions = soup.find('table', {'class': 'sortable'}).find('tbody').find_all('tr')
    match_participation = []
    matches_history = []
    player_answer_history = []
    temp_players = dict()
    for player_row in full_questions:
        tds = player_row.find_all('td')
        q_tds = tds[:6]
        # player_temp_username = str(tds[7].find('img')['title']).lower()
        player_temp_id = str(tds[7].find('a')['href'].split('?')[-1]) # just using the player ID, not username.
        # if player_temp_username == 'o' or player_temp_username.endswith('.') or player_temp_username == 'd':
        #     prof_url = constants['LLHEADER'] + tds[7].find('a')['href']
        #     prof_soup = BeautifulSoup(sess.get(prof_url).text, 'html.parser')
        #     player_temp_username = prof_soup.find('h1', {'class': 'namecss'}).text.strip().replace("'", '').lower()
        # if player_temp_username in change_id.keys():
        #     player_temp_username = change_id[player_temp_username]
        fft = 'F' in q_tds[0]['class'][0]
        q_correct = [None]*6 if fft else list(map(
            lambda q: False if (
                q['class'][0][1] == 'F' and season == 91 and md == 18 and rundle[1] in ['Glacier', 'Ravenna']
                ) else bool(int(q['class'][0][1])), q_tds))
        def_given = list(map(lambda q:
            int(q.text) if q.text.isnumeric() else (
                0 if q.text.lower() in ['', 'o'] else (
                2 if q.text == '`' and season in [62, 63, 64, 65] else None)
            ), q_tds))
        tot_correct, tot_pts = 'F', 0
        if not fft:
            tot_correct = sum(q_correct)
            if def_given[0] is not None: tot_pts = sum(np.multiply(q_correct, def_given))
            else: tot_pts = round(1.5*tot_correct)
        # player_temp_username = '_'.join(player_temp_username.split())
        # print(player_temp_id)
        if player_temp_id not in player_profiles.keys():
            player_profiles[player_temp_id] = build_base_player(player_temp_id)
            build_inverse()
        this_pp = player_profiles[player_temp_id]
        player_temp_username = str(this_pp['id'])
        # if 'name' in this_pp.keys(): player_temp_username = this_pp['name']
        # else: player_temp_username = this_pp['username']
        if player_temp_username.lower() == 'o\'brienm': player_temp_username = '_'.join(player_temp_username.replace("'", '_').split()).lower()
        elif player_temp_username.lower() == 'o\'brienp' and rundle[1] == 'Sugarloaf': player_temp_username = 'o_brienp'
        elif player_temp_username.lower() == 'o\'neillj' and rundle[1] not in ['Central', 'Seneca']: player_temp_username = 'o_neillj'
        elif player_temp_username.lower() == 'obrienj' and rundle[1] == 'Xanadu': player_temp_username = '45499'
        elif player_temp_username.lower() == 'oconnors' and rundle[1] not in ['Juniper', 'Magnolia']: player_temp_username = '34162'
        else: player_temp_username = '_'.join(player_temp_username.replace("'", '').split()).lower()
        temp_players[player_temp_username] = {'key': player_temp_username,
            'fft': fft, 'q_correct': q_correct, 'def_given': def_given,
            'tot_correct': tot_correct, 'tot_pts': tot_pts}
    # print(temp_players.keys())
    # print(temp_players.keys(), set(map(lambda m: str(m[6]).lower(), match_participation)))

    for match in matches:
        # p1_id, p2_id = '_'.join(
        #     match.contents[3].text.strip().split()).lower(), '_'.join(
        #     match.contents[7].text.strip().split()).lower()
        p1_key = '_'.join('?'.join(str(match.contents[1].find('a')['href']).split('?')[1:]).lower().split()).strip()
        p2_key = '_'.join('?'.join(str(match.contents[-2].find('a')['href']).split('?')[1:]).lower().split()).strip()
        # print(p1_key, p2_key)
        # if p1_key.isnumeric() and p1_key != '34162': p1_key = '_'.join(player_profiles[p1_key]['username'].split()).lower()
        # if p2_key.isnumeric() and p2_key != '34162': p2_key = '_'.join(player_profiles[p2_key]['username'].split()).lower()
        # print(p1_key, p2_key)
        if rundle[1] == 'Skyline':
            if p1_key == 'obrienm': p1_key = "o_brienm"
            elif p2_key == 'obrienm': p2_key = "o_brienm"
        if 'jacobs_s.' in [p1_key, p2_key]: # these matches just don't exist for whatever reason. Jacobs S. is an enigma
            continue
        elif season == 75 and 'oneillj' in [p1_key, p2_key]: # these also dont work
            continue
        p1_key, p2_key = p1_key.replace("'", ''), p2_key.replace("'", '')
        # if p1_key not in temp_players.keys():
        #     if p1_key in change_id.keys():
        #         p1_key = change_id[p1_key]
        #     else:
        #         p1_key = BeautifulSoup(sess.get(constants["LLHEADER"] + f'/profiles.php?{p1_key}').text,
        #             'html.parser').find('h1', {'class': 'namecss'}).text.strip().lower()
        # if p2_key not in temp_players.keys():
        #     if p2_key in change_id.keys():
        #         p2_key = change_id[p2_key]
        #     else: p2_key = BeautifulSoup(sess.get(constants["LLHEADER"] + f'/profiles.php?{p2_key}').text,
        #             'html.parser').find('h1', {'class': 'namecss'}).text.strip().lower()
        if p1_key == 'oneillj' and rundle[1] not in ['Central', 'Seneca']: p1_key = 'o_neillj'
        elif p2_key == 'oneillj' and rundle[1] not in ['Central', 'Seneca']: p2_key = 'o_neillj'
        if p1_key == 'obrienp' and rundle[1] == 'Sugarloaf': p1_key = 'o_brienp'
        elif p2_key == 'obrienp' and rundle[1] == 'Sugarloaf': p2_key = 'o_brienp'
        if p1_key == 'oconnors' and rundle[1] not in ['Juniper', 'Magnolia']: p1_key = '34162'
        elif p2_key == 'oconnors' and rundle[1] not in ['Juniper', 'Magnolia']: p2_key = '34162'
        if p1_key == 'o\'brienj' and rundle[1] == 'Xanadu': p1_key = '45499'
        elif p2_key == 'o\'brienj' and rundle[1] == 'Xanadu': p1_key = '45499'
        match_id = match.contents[5].find('a')['href'].split('.php?id=')[1]
        matches_history.append([match_id, *rundle, season, md])
        p1_key, p2_key = p1_key.replace("'", ''), p2_key.replace("'", '')
        p1, p2 = temp_players[p1_key], temp_players[p2_key]
        # there seem to have been actually 2-3 oconnors's.
        p1['id'], p2['id'] = p1_key.replace("'", ''), p2_key.replace("'", '')
        if p1['fft']:
            p1['result'] = 'F'
            p2['result'] = 'F' if p2['fft'] else 'W'
        elif p2['fft']: p1['result'], p2['result'] = 'W', 'F'
        elif p1['tot_pts'] == p2['tot_pts']: p1['result'], p2['result'] = 'T', 'T'
        elif p1['tot_pts'] > p2['tot_pts']: p1['result'], p2['result'] = 'W', 'L'
        else: p1['result'], p2['result'] = 'L', 'W'
        match_participation.append([
            match_id, season, md, *rundle,
            p1['id'], p1['result']
        ])
        match_participation.append([
            match_id, season, md, *rundle,
            p2['id'], p2['result']
        ])
        for qnum in range(6):
            player_answer_history.append([
                match_id, *rundle, season, md, qnum+1,
                p1['id'], p1['q_correct'][qnum], p1['def_given'][qnum]
            ])
            player_answer_history.append([
                match_id, *rundle, season, md, qnum+1,
                p2['id'], p2['q_correct'][qnum], p2['def_given'][qnum]
            ])
    matches_not_found = set(temp_players.keys()).difference(set(map(lambda m: str(m[6]).lower(), match_participation)))
    for pl in matches_not_found:
        match_participation.append([
            None, season, md, *rundle,
            pl, 'U'
        ])
        for qnum in range(6):
            player_answer_history.append([
                None, *rundle, season, md, qnum+1,
                pl, temp_players[pl]['q_correct'][qnum], temp_players[pl]['def_given'][qnum]
            ])
    return matches_history, match_participation, player_answer_history

def main_post_52(content):
    rundle, season, md = content['rundle'], content['season'], content['md']
    url = rundle_md_url(rundle, season, md)
    # print(url)
    gamepage = sess.get(url)
    html_text = gamepage.text
    soup = BeautifulSoup(html_text, 'html.parser')
    ret = dict()
    ret['matches_history'], ret['match_participation'], ret['player_answer_history'] = post_52(soup, rundle, season, md)
    return ret
main_post_52({'rundle': ['D', 'Ravenna', 1], 'season': 91, 'md': 18})
# Out:
# {'matches_history': [['5302346', 'D', 'Ravenna', 1, 91, 18],
#   ['5302347', 'D', 'Ravenna', 1, 91, 18],
#   ['5302348', 'D', 'Ravenna', 1, 91, 18],
#   ['5302349', 'D', 'Ravenna', 1, 91, 18],
#   ['5302350', 'D', 'Ravenna', 1, 91, 18],
#   ['5302351', 'D', 'Ravenna', 1, 91, 18],
#   ['5302352', 'D', 'Ravenna', 1, 91, 18],
#   ['5302353', 'D', 'Ravenna', 1, 91, 18],
#   ['5302354', 'D', 'Ravenna', 1, 91, 18],
#   ['5302355', 'D', 'Ravenna', 1, 91, 18],
#   ['5302356', 'D', 'Ravenna', 1, 91, 18],
#   ['5302357', 'D', 'Ravenna', 1, 91, 18],
#   ['5302358', 'D', 'Ravenna', 1, 91, 18],
#   ['5302359', 'D', 'Ravenna', 1, 91, 18],
#   ['5302360', 'D', 'Ravenna', 1, 91, 18],
#   ['5302361', 'D', 'Ravenna', 1, 91, 18],
#   ['5302362', 'D', 'Ravenna', 1, 91, 18]],
#  'match_participation': [['5302346', 91, 18, 'D', 'Ravenna', 1, '60038', 'T'],
#   ['5302346', 91, 18, 'D', 'Ravenna', 1, '25795', 'T'],
#   ['5302347', 91, 18, 'D', 'Ravenna', 1, '15084', 'L'],
#   ['5302347', 91, 18, 'D', 'Ravenna', 1, '50864', 'W'],
#   ['5302348', 91, 18, 'D', 'Ravenna', 1, '15798', 'T'],
#   ['5302348', 91, 18, 'D', 'Ravenna', 1, '50771', 'T'],
#   ['5302349', 91, 18, 'D', 'Ravenna', 1, '7542', 'T'],
#   ['5302349', 91, 18, 'D', 'Ravenna', 1, '48134', 'T'],
#   ['5302350', 91, 18, 'D', 'Ravenna', 1, '43513', 'W'],
#   ['5302350', 91, 18, 'D', 'Ravenna', 1, '1073', 'L'],
#   ['5302351', 91, 18, 'D', 'Ravenna', 1, '26390', 'W'],
#   ['5302351', 91, 18, 'D', 'Ravenna', 1, '11599', 'L'],
#   ['5302352', 91, 18, 'D', 'Ravenna', 1, '42684', 'W'],
#   ['5302352', 91, 18, 'D', 'Ravenna', 1, '13217', 'L'],
#   ['5302353', 91, 18, 'D', 'Ravenna', 1, '22847', 'W'],
#   ['5302353', 91, 18, 'D', 'Ravenna', 1, '40255', 'L'],
#   ['5302354', 91, 18, 'D', 'Ravenna', 1, '16452', 'L'],
#   ['5302354', 91, 18, 'D', 'Ravenna', 1, '18966', 'W'],
#   ['5302355', 91, 18, 'D', 'Ravenna', 1, '54353', 'T'],
#   ['5302355', 91, 18, 'D', 'Ravenna', 1, '53905', 'T'],
#   ['5302356', 91, 18, 'D', 'Ravenna', 1, '57794', 'L'],
#   ['5302356', 91, 18, 'D', 'Ravenna', 1, '4399', 'W'],
#   ['5302357', 91, 18, 'D', 'Ravenna', 1, '46887', 'W'],
#   ['5302357', 91, 18, 'D', 'Ravenna', 1, '52202', 'L'],
#   ['5302358', 91, 18, 'D', 'Ravenna', 1, '34237', 'W'],
#   ['5302358', 91, 18, 'D', 'Ravenna', 1, '52799', 'L'],
#   ['5302359', 91, 18, 'D', 'Ravenna', 1, '56877', 'W'],
#   ['5302359', 91, 18, 'D', 'Ravenna', 1, '21492', 'L'],
#   ['5302360', 91, 18, 'D', 'Ravenna', 1, '13603', 'T'],
#   ['5302360', 91, 18, 'D', 'Ravenna', 1, '58775', 'T'],
#   ['5302361', 91, 18, 'D', 'Ravenna', 1, '58820', 'W'],
#   ['5302361', 91, 18, 'D', 'Ravenna', 1, '15853', 'L'],
#   ['5302362', 91, 18, 'D', 'Ravenna', 1, '15682', 'L'],
#   ['5302362', 91, 18, 'D', 'Ravenna', 1, '39281', 'W']],
#  'player_answer_history': [['5302346',
#    'D',
#    'Ravenna',
#    1,
#    91,
#    18,
#    1,
#    '60038',
#    False,
#    0],
#   ['5302346', 'D', 'Ravenna', 1, 91, 18, 1, '25795', False, 0],
#   ['5302346', 'D', 'Ravenna', 1, 91, 18, 2, '60038', True, 1],
#   ['5302346', 'D', 'Ravenna', 1, 91, 18, 2, '25795', True, 2],
#   ['5302346', 'D', 'Ravenna', 1, 91, 18, 3, '60038', False, 2],
#   ['5302346', 'D', 'Ravenna', 1, 91, 18, 3, '25795', False, 3],
#   ['5302346', 'D', 'Ravenna', 1, 91, 18, 4, '60038', True, 2],
#   ['5302346', 'D', 'Ravenna', 1, 91, 18, 4, '25795', False, 2],
#   ['5302346', 'D', 'Ravenna', 1, 91, 18, 5, '60038', False, 3],
#   ['5302346', 'D', 'Ravenna', 1, 91, 18, 5, '25795', False, 1],
#   ['5302346', 'D', 'Ravenna', 1, 91, 18, 6, '60038', False, 1],
#   ['5302346', 'D', 'Ravenna', 1, 91, 18, 6, '25795', True, 1],
#   ['5302347', 'D', 'Ravenna', 1, 91, 18, 1, '15084', True, 0],
#   ['5302347', 'D', 'Ravenna', 1, 91, 18, 1, '50864', True, 0],
#   ['5302347', 'D', 'Ravenna', 1, 91, 18, 2, '15084', False, 2],
#   ['5302347', 'D', 'Ravenna', 1, 91, 18, 2, '50864', True, 1],
#   ['5302347', 'D', 'Ravenna', 1, 91, 18, 3, '15084', False, 1],
#   ['5302347', 'D', 'Ravenna', 1, 91, 18, 3, '50864', False, 1],
#   ['5302347', 'D', 'Ravenna', 1, 91, 18, 4, '15084', True, 3],
#   ['5302347', 'D', 'Ravenna', 1, 91, 18, 4, '50864', False, 2],
#   ['5302347', 'D', 'Ravenna', 1, 91, 18, 5, '15084', False, 2],
#   ['5302347', 'D', 'Ravenna', 1, 91, 18, 5, '50864', True, 3],
#   ['5302347', 'D', 'Ravenna', 1, 91, 18, 6, '15084', False, 1],
#   ['5302347', 'D', 'Ravenna', 1, 91, 18, 6, '50864', True, 2],
#   ['5302348', 'D', 'Ravenna', 1, 91, 18, 1, '15798', False, 3],
#   ['5302348', 'D', 'Ravenna', 1, 91, 18, 1, '50771', True, 0],
#   ['5302348', 'D', 'Ravenna', 1, 91, 18, 2, '15798', True, 0],
#   ['5302348', 'D', 'Ravenna', 1, 91, 18, 2, '50771', True, 2],
#   ['5302348', 'D', 'Ravenna', 1, 91, 18, 3, '15798', False, 2],
#   ['5302348', 'D', 'Ravenna', 1, 91, 18, 3, '50771', False, 3],
#   ['5302348', 'D', 'Ravenna', 1, 91, 18, 4, '15798', True, 2],
#   ['5302348', 'D', 'Ravenna', 1, 91, 18, 4, '50771', True, 2],
#   ['5302348', 'D', 'Ravenna', 1, 91, 18, 5, '15798', True, 1],
#   ['5302348', 'D', 'Ravenna', 1, 91, 18, 5, '50771', False, 1],
#   ['5302348', 'D', 'Ravenna', 1, 91, 18, 6, '15798', True, 1],
#   ['5302348', 'D', 'Ravenna', 1, 91, 18, 6, '50771', False, 1],
#   ['5302349', 'D', 'Ravenna', 1, 91, 18, 1, '7542', True, 1],
#   ['5302349', 'D', 'Ravenna', 1, 91, 18, 1, '48134', True, 1],
#   ['5302349', 'D', 'Ravenna', 1, 91, 18, 2, '7542', True, 2],
#   ['5302349', 'D', 'Ravenna', 1, 91, 18, 2, '48134', True, 2],
#   ['5302349', 'D', 'Ravenna', 1, 91, 18, 3, '7542', False, 2],
#   ['5302349', 'D', 'Ravenna', 1, 91, 18, 3, '48134', False, 2],
#   ['5302349', 'D', 'Ravenna', 1, 91, 18, 4, '7542', True, 1],
#   ['5302349', 'D', 'Ravenna', 1, 91, 18, 4, '48134', True, 0],
#   ['5302349', 'D', 'Ravenna', 1, 91, 18, 5, '7542', False, 3],
#   ['5302349', 'D', 'Ravenna', 1, 91, 18, 5, '48134', False, 3],
#   ['5302349', 'D', 'Ravenna', 1, 91, 18, 6, '7542', False, 0],
#   ['5302349', 'D', 'Ravenna', 1, 91, 18, 6, '48134', True, 1],
#   ['5302350', 'D', 'Ravenna', 1, 91, 18, 1, '43513', True, 1],
#   ['5302350', 'D', 'Ravenna', 1, 91, 18, 1, '1073', True, 0],
#   ['5302350', 'D', 'Ravenna', 1, 91, 18, 2, '43513', False, 0],
#   ['5302350', 'D', 'Ravenna', 1, 91, 18, 2, '1073', False, 1],
#   ['5302350', 'D', 'Ravenna', 1, 91, 18, 3, '43513', False, 3],
#   ['5302350', 'D', 'Ravenna', 1, 91, 18, 3, '1073', False, 2],
#   ['5302350', 'D', 'Ravenna', 1, 91, 18, 4, '43513', True, 2],
#   ['5302350', 'D', 'Ravenna', 1, 91, 18, 4, '1073', False, 1],
#   ['5302350', 'D', 'Ravenna', 1, 91, 18, 5, '43513', False, 2],
#   ['5302350', 'D', 'Ravenna', 1, 91, 18, 5, '1073', True, 2],
#   ['5302350', 'D', 'Ravenna', 1, 91, 18, 6, '43513', False, 1],
#   ['5302350', 'D', 'Ravenna', 1, 91, 18, 6, '1073', False, 3],
#   ['5302351', 'D', 'Ravenna', 1, 91, 18, 1, '26390', False, 0],
#   ['5302351', 'D', 'Ravenna', 1, 91, 18, 1, '11599', True, 2],
#   ['5302351', 'D', 'Ravenna', 1, 91, 18, 2, '26390', True, 1],
#   ['5302351', 'D', 'Ravenna', 1, 91, 18, 2, '11599', True, 1],
#   ['5302351', 'D', 'Ravenna', 1, 91, 18, 3, '26390', False, 2],
#   ['5302351', 'D', 'Ravenna', 1, 91, 18, 3, '11599', False, 3],
#   ['5302351', 'D', 'Ravenna', 1, 91, 18, 4, '26390', True, 1],
#   ['5302351', 'D', 'Ravenna', 1, 91, 18, 4, '11599', False, 0],
#   ['5302351', 'D', 'Ravenna', 1, 91, 18, 5, '26390', True, 3],
#   ['5302351', 'D', 'Ravenna', 1, 91, 18, 5, '11599', False, 2],
#   ['5302351', 'D', 'Ravenna', 1, 91, 18, 6, '26390', True, 2],
#   ['5302351', 'D', 'Ravenna', 1, 91, 18, 6, '11599', False, 1],
#   ['5302352', 'D', 'Ravenna', 1, 91, 18, 1, '42684', True, 0],
#   ['5302352', 'D', 'Ravenna', 1, 91, 18, 1, '13217', False, 0],
#   ['5302352', 'D', 'Ravenna', 1, 91, 18, 2, '42684', True, 1],
#   ['5302352', 'D', 'Ravenna', 1, 91, 18, 2, '13217', False, 2],
#   ['5302352', 'D', 'Ravenna', 1, 91, 18, 3, '42684', False, 3],
#   ['5302352', 'D', 'Ravenna', 1, 91, 18, 3, '13217', False, 1],
#   ['5302352', 'D', 'Ravenna', 1, 91, 18, 4, '42684', True, 1],
#   ['5302352', 'D', 'Ravenna', 1, 91, 18, 4, '13217', True, 1],
#   ['5302352', 'D', 'Ravenna', 1, 91, 18, 5, '42684', True, 2],
#   ['5302352', 'D', 'Ravenna', 1, 91, 18, 5, '13217', True, 3],
#   ['5302352', 'D', 'Ravenna', 1, 91, 18, 6, '42684', True, 2],
#   ['5302352', 'D', 'Ravenna', 1, 91, 18, 6, '13217', False, 2],
#   ['5302353', 'D', 'Ravenna', 1, 91, 18, 1, '22847', True, 1],
#   ['5302353', 'D', 'Ravenna', 1, 91, 18, 1, '40255', False, 1],
#   ['5302353', 'D', 'Ravenna', 1, 91, 18, 2, '22847', True, 0],
#   ['5302353', 'D', 'Ravenna', 1, 91, 18, 2, '40255', False, 2],
#   ['5302353', 'D', 'Ravenna', 1, 91, 18, 3, '22847', False, 3],
#   ['5302353', 'D', 'Ravenna', 1, 91, 18, 3, '40255', False, 3],
#   ['5302353', 'D', 'Ravenna', 1, 91, 18, 4, '22847', True, 1],
#   ['5302353', 'D', 'Ravenna', 1, 91, 18, 4, '40255', True, 2],
#   ['5302353', 'D', 'Ravenna', 1, 91, 18, 5, '22847', True, 2],
#   ['5302353', 'D', 'Ravenna', 1, 91, 18, 5, '40255', False, 1],
#   ['5302353', 'D', 'Ravenna', 1, 91, 18, 6, '22847', True, 2],
#   ['5302353', 'D', 'Ravenna', 1, 91, 18, 6, '40255', False, 0],
#   ['5302354', 'D', 'Ravenna', 1, 91, 18, 1, '16452', False, 1],
#   ['5302354', 'D', 'Ravenna', 1, 91, 18, 1, '18966', True, 0],
#   ['5302354', 'D', 'Ravenna', 1, 91, 18, 2, '16452', True, 0],
#   ['5302354', 'D', 'Ravenna', 1, 91, 18, 2, '18966', False, 2],
#   ['5302354', 'D', 'Ravenna', 1, 91, 18, 3, '16452', False, 3],
#   ['5302354', 'D', 'Ravenna', 1, 91, 18, 3, '18966', False, 1],
#   ['5302354', 'D', 'Ravenna', 1, 91, 18, 4, '16452', True, 2],
#   ['5302354', 'D', 'Ravenna', 1, 91, 18, 4, '18966', False, 1],
#   ['5302354', 'D', 'Ravenna', 1, 91, 18, 5, '16452', False, 2],
#   ['5302354', 'D', 'Ravenna', 1, 91, 18, 5, '18966', True, 3],
#   ['5302354', 'D', 'Ravenna', 1, 91, 18, 6, '16452', False, 1],
#   ['5302354', 'D', 'Ravenna', 1, 91, 18, 6, '18966', True, 2],
#   ['5302355', 'D', 'Ravenna', 1, 91, 18, 1, '54353', True, 0],
#   ['5302355', 'D', 'Ravenna', 1, 91, 18, 1, '53905', False, 1],
#   ['5302355', 'D', 'Ravenna', 1, 91, 18, 2, '54353', True, 0],
#   ['5302355', 'D', 'Ravenna', 1, 91, 18, 2, '53905', False, 0],
#   ['5302355', 'D', 'Ravenna', 1, 91, 18, 3, '54353', False, 0],
#   ['5302355', 'D', 'Ravenna', 1, 91, 18, 3, '53905', False, 3],
#   ['5302355', 'D', 'Ravenna', 1, 91, 18, 4, '54353', True, 0],
#   ['5302355', 'D', 'Ravenna', 1, 91, 18, 4, '53905', False, 2],
#   ['5302355', 'D', 'Ravenna', 1, 91, 18, 5, '54353', False, 0],
#   ['5302355', 'D', 'Ravenna', 1, 91, 18, 5, '53905', False, 2],
#   ['5302355', 'D', 'Ravenna', 1, 91, 18, 6, '54353', True, 0],
#   ['5302355', 'D', 'Ravenna', 1, 91, 18, 6, '53905', False, 1],
#   ['5302356', 'D', 'Ravenna', 1, 91, 18, 1, '57794', False, 2],
#   ['5302356', 'D', 'Ravenna', 1, 91, 18, 1, '4399', True, 2],
#   ['5302356', 'D', 'Ravenna', 1, 91, 18, 2, '57794', True, 1],
#   ['5302356', 'D', 'Ravenna', 1, 91, 18, 2, '4399', True, 1],
#   ['5302356', 'D', 'Ravenna', 1, 91, 18, 3, '57794', False, 3],
#   ['5302356', 'D', 'Ravenna', 1, 91, 18, 3, '4399', False, 2],
#   ['5302356', 'D', 'Ravenna', 1, 91, 18, 4, '57794', True, 0],
#   ['5302356', 'D', 'Ravenna', 1, 91, 18, 4, '4399', True, 1],
#   ['5302356', 'D', 'Ravenna', 1, 91, 18, 5, '57794', False, 2],
#   ['5302356', 'D', 'Ravenna', 1, 91, 18, 5, '4399', True, 3],
#   ['5302356', 'D', 'Ravenna', 1, 91, 18, 6, '57794', True, 1],
#   ['5302356', 'D', 'Ravenna', 1, 91, 18, 6, '4399', True, 0],
#   ['5302357', 'D', 'Ravenna', 1, 91, 18, 1, '46887', False, 1],
#   ['5302357', 'D', 'Ravenna', 1, 91, 18, 1, '52202', True, 1],
#   ['5302357', 'D', 'Ravenna', 1, 91, 18, 2, '46887', True, 3],
#   ['5302357', 'D', 'Ravenna', 1, 91, 18, 2, '52202', True, 2],
#   ['5302357', 'D', 'Ravenna', 1, 91, 18, 3, '46887', False, 2],
#   ['5302357', 'D', 'Ravenna', 1, 91, 18, 3, '52202', False, 2],
#   ['5302357', 'D', 'Ravenna', 1, 91, 18, 4, '46887', True, 0],
#   ['5302357', 'D', 'Ravenna', 1, 91, 18, 4, '52202', False, 1],
#   ['5302357', 'D', 'Ravenna', 1, 91, 18, 5, '46887', True, 2],
#   ['5302357', 'D', 'Ravenna', 1, 91, 18, 5, '52202', True, 0],
#   ['5302357', 'D', 'Ravenna', 1, 91, 18, 6, '46887', False, 1],
#   ['5302357', 'D', 'Ravenna', 1, 91, 18, 6, '52202', False, 3],
#   ['5302358', 'D', 'Ravenna', 1, 91, 18, 1, '34237', False, 1],
#   ['5302358', 'D', 'Ravenna', 1, 91, 18, 1, '52799', True, 1],
#   ['5302358', 'D', 'Ravenna', 1, 91, 18, 2, '34237', True, 2],
#   ['5302358', 'D', 'Ravenna', 1, 91, 18, 2, '52799', True, 1],
#   ['5302358', 'D', 'Ravenna', 1, 91, 18, 3, '34237', False, 3],
#   ['5302358', 'D', 'Ravenna', 1, 91, 18, 3, '52799', False, 3],
#   ['5302358', 'D', 'Ravenna', 1, 91, 18, 4, '34237', True, 0],
#   ['5302358', 'D', 'Ravenna', 1, 91, 18, 4, '52799', True, 2],
#   ['5302358', 'D', 'Ravenna', 1, 91, 18, 5, '34237', True, 2],
#   ['5302358', 'D', 'Ravenna', 1, 91, 18, 5, '52799', True, 0],
#   ['5302358', 'D', 'Ravenna', 1, 91, 18, 6, '34237', True, 1],
#   ['5302358', 'D', 'Ravenna', 1, 91, 18, 6, '52799', False, 2],
#   ['5302359', 'D', 'Ravenna', 1, 91, 18, 1, '56877', True, 0],
#   ['5302359', 'D', 'Ravenna', 1, 91, 18, 1, '21492', True, 0],
#   ['5302359', 'D', 'Ravenna', 1, 91, 18, 2, '56877', True, 2],
#   ['5302359', 'D', 'Ravenna', 1, 91, 18, 2, '21492', False, 1],
#   ['5302359', 'D', 'Ravenna', 1, 91, 18, 3, '56877', True, 2],
#   ['5302359', 'D', 'Ravenna', 1, 91, 18, 3, '21492', False, 3],
#   ['5302359', 'D', 'Ravenna', 1, 91, 18, 4, '56877', True, 1],
#   ['5302359', 'D', 'Ravenna', 1, 91, 18, 4, '21492', False, 1],
#   ['5302359', 'D', 'Ravenna', 1, 91, 18, 5, '56877', True, 3],
#   ['5302359', 'D', 'Ravenna', 1, 91, 18, 5, '21492', True, 2],
#   ['5302359', 'D', 'Ravenna', 1, 91, 18, 6, '56877', False, 1],
#   ['5302359', 'D', 'Ravenna', 1, 91, 18, 6, '21492', False, 2],
#   ['5302360', 'D', 'Ravenna', 1, 91, 18, 1, '13603', False, 2],
#   ['5302360', 'D', 'Ravenna', 1, 91, 18, 1, '58775', True, 2],
#   ['5302360', 'D', 'Ravenna', 1, 91, 18, 2, '13603', True, 0],
#   ['5302360', 'D', 'Ravenna', 1, 91, 18, 2, '58775', False, 1],
#   ['5302360', 'D', 'Ravenna', 1, 91, 18, 3, '13603', False, 3],
#   ['5302360', 'D', 'Ravenna', 1, 91, 18, 3, '58775', False, 3],
#   ['5302360', 'D', 'Ravenna', 1, 91, 18, 4, '13603', True, 1],
#   ['5302360', 'D', 'Ravenna', 1, 91, 18, 4, '58775', True, 0],
#   ['5302360', 'D', 'Ravenna', 1, 91, 18, 5, '13603', True, 1],
#   ['5302360', 'D', 'Ravenna', 1, 91, 18, 5, '58775', True, 2],
#   ['5302360', 'D', 'Ravenna', 1, 91, 18, 6, '13603', True, 2],
#   ['5302360', 'D', 'Ravenna', 1, 91, 18, 6, '58775', False, 1],
#   ['5302361', 'D', 'Ravenna', 1, 91, 18, 1, '58820', True, 0],
#   ['5302361', 'D', 'Ravenna', 1, 91, 18, 1, '15853', False, 2],
#   ['5302361', 'D', 'Ravenna', 1, 91, 18, 2, '58820', True, 1],
#   ['5302361', 'D', 'Ravenna', 1, 91, 18, 2, '15853', True, 1],
#   ['5302361', 'D', 'Ravenna', 1, 91, 18, 3, '58820', True, 1],
#   ['5302361', 'D', 'Ravenna', 1, 91, 18, 3, '15853', False, 3],
#   ['5302361', 'D', 'Ravenna', 1, 91, 18, 4, '58820', True, 2],
#   ['5302361', 'D', 'Ravenna', 1, 91, 18, 4, '15853', True, 0],
#   ['5302361', 'D', 'Ravenna', 1, 91, 18, 5, '58820', True, 3],
#   ['5302361', 'D', 'Ravenna', 1, 91, 18, 5, '15853', True, 1],
#   ['5302361', 'D', 'Ravenna', 1, 91, 18, 6, '58820', True, 2],
#   ['5302361', 'D', 'Ravenna', 1, 91, 18, 6, '15853', False, 2],
#   ['5302362', 'D', 'Ravenna', 1, 91, 18, 1, '15682', True, 1],
#   ['5302362', 'D', 'Ravenna', 1, 91, 18, 1, '39281', False, 0],
#   ['5302362', 'D', 'Ravenna', 1, 91, 18, 2, '15682', False, 0],
#   ['5302362', 'D', 'Ravenna', 1, 91, 18, 2, '39281', True, 1],
#   ['5302362', 'D', 'Ravenna', 1, 91, 18, 3, '15682', False, 2],
#   ['5302362', 'D', 'Ravenna', 1, 91, 18, 3, '39281', False, 2],
#   ['5302362', 'D', 'Ravenna', 1, 91, 18, 4, '15682', False, 3],
#   ['5302362', 'D', 'Ravenna', 1, 91, 18, 4, '39281', True, 3],
#   ['5302362', 'D', 'Ravenna', 1, 91, 18, 5, '15682', False, 2],
#   ['5302362', 'D', 'Ravenna', 1, 91, 18, 5, '39281', True, 1],
#   ['5302362', 'D', 'Ravenna', 1, 91, 18, 6, '15682', False, 1],
#   ['5302362', 'D', 'Ravenna', 1, 91, 18, 6, '39281', True, 2]]}

# %%
# do all R rundles in first runthrough, find names to add to id chg dict.
# do all non-R rundles md1 runthrough, find other rundle errs
with open('alt_ids.json', 'r') as rp:
    change_id = json.load(rp)
for season in range(91, 94):
    season_prep_data = []
    cur_rundles = all_rundles_by_season[str(season)]['rundles']
    # cur_rundles = list(filter(lambda rundle: rundle[0] == 'R',
    #     all_rundles_by_season[str(season)]['rundles']))
    ovr_results = []
    error_results = []
    for md in range(1, 26):
    # for md in range(1, 2):
        for rundle in cur_rundles:
            season_prep_data.append({'rundle': rundle, 'season': season, 'md': md})
    try:
        tot, err = perform_web_requests(season_prep_data, 8, ovr_results, error_results, main_post_52)
        with open(f'./FULL_DATA/LL{season}/results.json', 'w') as fp:
            json.dump(tot, fp)
        with open(f'./FULL_DATA/LL{season}/rundle_errors.json', 'w') as fp:
            json.dump(err, fp, indent=4)
        with open('player_profiles.json', 'w') as fp:
            json.dump(player_profiles, fp)
        with open('player_profiles.json', 'r') as fp:
            player_profiles = json.load(fp)
        with open('pp_by_username.json', 'w') as fp:
            json.dump(by_username, fp)
        with open('pp_by_username.json', 'r') as fp:
            by_username = json.load(fp)
        print(f'successfully completed season {season}')
    except:
        print(f'season {season} failed')
    with open('alt_ids.json', 'w') as wp:
        json.dump(change_id, wp)
    with open('alt_ids.json', 'r') as rp:
        change_id = json.load(rp)
# Out:
# broke on {'rundle': ['D', 'Veldt', 2], 'season': 91, 'md': 1}
# 1000 complete
# broke on {'rundle': ['C', 'Sierra', 2], 'season': 91, 'md': 2}
# broke on {'rundle': ['D', 'Sierra', 1], 'season': 91, 'md': 2}
# 2000 complete
# broke on {'rundle': ['C', 'Laguna', 2], 'season': 91, 'md': 3}
# broke on {'rundle': ['C', 'Laguna', 1], 'season': 91, 'md': 3}
# broke on {'rundle': ['E', 'Keystone', 2], 'season': 91, 'md': 3}
# broke on {'rundle': ['B', 'Laguna', 0], 'season': 91, 'md': 3}
# broke on {'rundle': ['A', 'Laguna', 0], 'season': 91, 'md': 3}
# broke on {'rundle': ['B', 'Xanadu', 0], 'season': 91, 'md': 3}
# broke on {'rundle': ['A', 'Xanadu', 0], 'season': 91, 'md': 3}
# broke on {'rundle': ['E', 'Woodlands', 1], 'season': 91, 'md': 3}
# 3000 complete
# broke on {'rundle': ['E', 'Tidewater', 1], 'season': 91, 'md': 4}
# broke on {'rundle': ['D', 'Mesa', 1], 'season': 91, 'md': 5}
# 4000 complete
# broke on {'rundle': ['C', 'Blue', 2], 'season': 91, 'md': 6}
# 5000 complete
# 6000 complete
# broke on {'rundle': ['E', 'Palisade', 2], 'season': 91, 'md': 8}
# broke on {'rundle': ['D', 'Valley', 2], 'season': 91, 'md': 8}
# 7000 complete
# 8000 complete
# 9000 complete
# 10000 complete
# 11000 complete
# 12000 complete
# 13000 complete
# 14000 complete
# broke on {'rundle': ['E', 'Glacier', 1], 'season': 91, 'md': 18}
# broke on {'rundle': ['D', 'Isthmus', 1], 'season': 91, 'md': 18}
# 15000 complete
# broke on {'rundle': ['D', 'Ravenna', 1], 'season': 91, 'md': 18}
# broke on {'rundle': ['C', 'Boardwalk', 1], 'season': 91, 'md': 19}
# 16000 complete
# 17000 complete
# 18000 complete
# 19000 complete
# 20000 complete
# 21000 complete
# time with 21580 requests, 8 workers: 2275.725008249283, errors: 20
# successfully completed season 91
# broke on {'rundle': ['B', 'Outback', 0], 'season': 92, 'md': 1}
# broke on {'rundle': ['A', 'Outback', 0], 'season': 92, 'md': 1}
# broke on {'rundle': ['C', 'Outback', 1], 'season': 92, 'md': 1}
# broke on {'rundle': ['E', 'Taiga', 1], 'season': 92, 'md': 1}
# broke on {'rundle': ['A', 'Central', 0], 'season': 92, 'md': 2}
# broke on {'rundle': ['C', 'Central', 1], 'season': 92, 'md': 2}
# broke on {'rundle': ['C', 'Central', 2], 'season': 92, 'md': 2}
# broke on {'rundle': ['R', 'Centennial', 0], 'season': 92, 'md': 2}
# broke on {'rundle': ['E', 'Centennial', 2], 'season': 92, 'md': 2}
# broke on {'rundle': ['B', 'Central', 0], 'season': 92, 'md': 2}
# broke on {'rundle': ['D', 'Central', 1], 'season': 92, 'md': 2}
# 1000 complete
# broke on {'rundle': ['D', 'Magnolia', 1], 'season': 92, 'md': 2}
# broke on {'rundle': ['D', 'Riviera', 1], 'season': 92, 'md': 2}
# broke on {'rundle': ['C', 'Galaxy', 2], 'season': 92, 'md': 3}
# 2000 complete
# broke on {'rundle': ['D', 'Outback', 2], 'season': 92, 'md': 3}
# broke on {'rundle': ['D', 'Citadel', 1], 'season': 92, 'md': 4}
# 3000 complete
# broke on {'rundle': ['B', 'Atlantic', 0], 'season': 92, 'md': 5}
# 4000 complete
# 5000 complete
# 6000 complete
# 7000 complete
# 8000 complete
# broke on {'rundle': ['C', 'Ravenna', 2], 'season': 92, 'md': 10}
# 9000 complete
# 10000 complete
# 11000 complete
# 12000 complete
# 13000 complete
# 14000 complete
# broke on {'rundle': ['E', 'Prairie', 1], 'season': 92, 'md': 17}
# 15000 complete
# broke on {'rundle': ['E', 'Serengeti', 2], 'season': 92, 'md': 18}
# 16000 complete
# broke on {'rundle': ['E', 'Nova', 2], 'season': 92, 'md': 19}
# 17000 complete
# 18000 complete
# broke on {'rundle': ['D', 'Evergreen', 2], 'season': 92, 'md': 22}
# 19000 complete
# 20000 complete
# 21000 complete
# time with 21953 requests, 8 workers: 2389.376475095749, errors: 22
# successfully completed season 92
# broke on {'rundle': ['A', 'Outback', 0], 'season': 93, 'md': 1}
# broke on {'rundle': ['C', 'Taiga', 2], 'season': 93, 'md': 1}
# broke on {'rundle': ['D', 'Centennial', 1], 'season': 93, 'md': 2}
# 1000 complete
# 2000 complete
# 3000 complete
# 4000 complete
# 5000 complete
# broke on {'rundle': ['D', 'Nebula', 1], 'season': 93, 'md': 7}
# 6000 complete
# broke on {'rundle': ['A', 'Metro', 0], 'season': 93, 'md': 8}broke on {'rundle': ['E', 'Mesa', 2], 'season': 93, 'md': 8}
#
# 7000 complete
# 8000 complete
# 9000 complete
# 10000 complete
# 11000 complete
# 12000 complete
# 13000 complete
# 14000 complete
# 15000 complete
# broke on {'rundle': ['E', 'Citadel', 2], 'season': 93, 'md': 19}
# broke on {'rundle': ['E', 'Hinterland', 2], 'season': 93, 'md': 19}
# 16000 complete
# 17000 complete
# 18000 complete
# broke on {'rundle': ['E', 'Archipelago', 1], 'season': 93, 'md': 22}
# broke on {'rundle': ['D', 'Archipelago', 2], 'season': 93, 'md': 22}
# broke on {'rundle': ['D', 'Meadow', 1], 'season': 93, 'md': 22}
# broke on {'rundle': ['C', 'Sunrise', 2], 'season': 93, 'md': 22}
# 19000 complete
# 20000 complete
# 21000 complete
# time with 21688 requests, 8 workers: 2407.9035398960114, errors: 12
# successfully completed season 93

# %%
for season in range(91, 92):
    with open(f'./FULL_DATA/LL{season}/results.json', 'r') as fp:
        seas_results = json.load(fp)
    with open(f'./FULL_DATA/LL{season}/rundle_errors.json', 'r') as fp:
        seas_errs = json.load(fp)
    print(len(seas_results), len(seas_errs))
    new_tot, new_err = perform_web_requests(seas_errs, 8, [], [], main_post_52)
    seas_results.extend(new_tot)
    print(len(seas_results))
    with open(f'./FULL_DATA/LL{season}/results.json', 'w') as fp:
        json.dump(seas_results, fp)
    with open(f'./FULL_DATA/LL{season}/rundle_errors.json', 'w') as fp:
        json.dump(new_err, fp)
# Out:
# 21598 2
# time with 2 requests, 8 workers: 0.651007890701294, errors: 0
# 21600

# %%
err
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-ea5d7e39dd60> in <module>
# ----> 1 err
#
# NameError: name 'err' is not defined

# %%
def get_rundle_matchday(rundle: list, season: int, md: int, match_history:list=[],
    player_rundle_history:list=[], match_participation:list=[], pp:dict=dict()):
    url = rundle_md_url(rundle, season, md)
    gamepage = sess.get(url)
    html_text = gamepage.text
    soup = BeautifulSoup(html_text, 'html.parser')
    if season <= 38: #LL30-38
        # header_text = 'Rundle ' + (rundle[0] if rundle[1] == 'League' or season <= 33 else rundle[0] + ' ' + rundle[1])
        # matches = soup.find(text=header_text).parent.next_element.next_element.find_all('div', {'class': 'sbGame'})
        matches = pre_38(soup, rundle, season, md)
    elif season == 51 and md >= 7: # Thorsten not at all consistent
        matches = soup.find('table', {'class': 'tblResults2'}).find_all('tr')
    elif season <= 51: #LL39-51
        matches = soup.find('table', {'class': 'tblResults'}).find_all('tr')
    else: #LL52-present
        matches = soup.find('table', {'class': 'gamelinetbl'}).find_all('tr')
    for match in matches:
        if season <= 38: match_id, p1, p2 = pre_38(match)
        elif season == 51 and md >= 7: match_id, p1, p2 = special_51(match)
        elif season <= 51: match_id, p1, p2 = classic_39_51(match)
        else: match_id, p1, p2 = post_52(match)
        if p1['input'] == False:
            p1['input'], p2['input'] = fucky(soup, str(p1['id']), str(p2['id']))
        p1_result, p2_result = format_match_result(p1['input'], p2['input'])
        if str(p1['id']).isnumeric():
            p1['id'], p2['id'] = int(p1['id']), int(p2['id'])
            p1['old_id'], p2['old_id'] = p1['id'], p2['id']
            if not p1['id'] in pp.keys():
                pp[p1['old_id']] = p1['id']
            if not p2['id'] in pp.keys():
                pp[p2['old_id']] = p2['id']
        if md == 1:
            if (season == 30 or rundle[0] == 'R'):
                if not str(p1['id']).isnumeric():
                    p1['id'], p2['id'] = '_'.join(p1['id'].split()), '_'.join(p2['id'].split())
                    if not p1['id'] in pp.keys():
                        p1['old_id'] = p1['id']
                        p1_old_url = f'/profiles/{p1["id"]}.shtml' if season <= 51 else f'/profiles.php?{p1["id"]}'
                        p1['id'] = int_or_float_or_str(sess.get(constants["LLHEADER"] + p1_old_url).url.split('?')[-1])
                        pp[p1['old_id']] = p1['id']
                    if not p2['id'] in pp.keys():
                        p2['old_id'] = p2['id']
                        p2_old_url = f'/profiles/{p2["id"]}.shtml' if season <= 51 else f'/profiles.php?{p2["id"]}'
                        p2['id'] = int_or_float_or_str(sess.get(constants["LLHEADER"] + p2_old_url).url.split('?')[-1])
                        pp[p2['old_id']] = p2['id']
            player_rundle_history.append([p1['id'], season, md, rundle[0], rundle[1], rundle[2]])
            player_rundle_history.append([p2['id'], season, md, rundle[0], rundle[1], rundle[2]])
        match_participation.append([match_id, p1['id'], p1_result])
        match_participation.append([match_id, p2['id'], p2_result])
    return player_rundle_history, match_participation, pp
# get_rundle_matchday(['D', 'Magnolia', 1], 80, 21)

# %%
player_rundle_history, match_participation, player_profile = [], [], dict()
with open('rundles_by_season.json', 'r') as fp:
    fr = json.load(fp)
full_rundles = []
# for key in fr.keys():
#     full_rundles.extend(fr[key]['rundles'])
# full_rundles
import time
st = time.time()
for season in range(30, 94):
    this_season_rundles = fr[str(season)]['rundles']
    for md in range(1, 21 if season <= 38 else 26):
        for rundle in this_season_rundles:
            try:
                player_rundle_history, match_participation, player_profile = get_rundle_matchday(
                    rundle, season, md, player_rundle_history, match_participation, player_profile
                )
            except:
                print(f'Failed on LL{season}, md {md}, rundle {rundle}, url: {rundle_md_url(rundle, season, md)}')
    print(f'completed LL{season}, total time: {time.time()-st}')
    st = time.time()
try:
    with open('match_participation.json', 'w') as a:
        json.dump(match_participation, a)
except:
    print('could not save match participation data')
try:
    with open('player_rundle_history.json', 'w') as a:
        json.dump(player_rundle_history, a)
except:
    print('could not save player rundle history data')
try:
    with open('player_profile_old_ids.json', 'w') as a:
        json.dump(player_profile, a)
except:
    print('could not save profile data')
# Out:
# completed LL30, total time: 63.94884777069092
# completed LL31, total time: 7.904952049255371
# completed LL32, total time: 16.15006685256958
# completed LL33, total time: 16.884157180786133
# completed LL34, total time: 32.05800104141235
# completed LL35, total time: 33.9595308303833
# completed LL36, total time: 34.343120098114014
# completed LL37, total time: 32.774303913116455
# completed LL38, total time: 37.54530692100525
# completed LL39, total time: 36.277426958084106
# completed LL40, total time: 33.288006067276
# completed LL41, total time: 44.730040073394775
# completed LL42, total time: 54.36037826538086
# completed LL43, total time: 62.04588174819946
# completed LL44, total time: 66.23294591903687
# completed LL45, total time: 70.78969597816467
# Failed on LL46, md 1, rundle ['R', 'Atlantic', 0], url: https://www.learnedleague.com/ll46/questions/ll46md01R_Atlanticresults.shtml
# completed LL46, total time: 73.28983497619629
# completed LL47, total time: 94.33732295036316
# completed LL48, total time: 105.09880495071411
# completed LL49, total time: 114.36065101623535
# completed LL50, total time: 129.7183940410614
# completed LL51, total time: 182.91262102127075
# completed LL52, total time: 353.7874870300293
# completed LL53, total time: 391.5151581764221
# completed LL54, total time: 384.36169815063477
# completed LL55, total time: 429.57801699638367
# completed LL56, total time: 561.4892499446869
# completed LL57, total time: 700.3090288639069
# completed LL58, total time: 813.1446359157562
# completed LL59, total time: 829.64377617836
# Failed on LL60, md 15, rundle ['B', 'Coastal', 0], url: https://www.learnedleague.com/match.php?60&15&B_Coastal
# completed LL60, total time: 663.8280000686646
# completed LL61, total time: 768.2108211517334
# completed LL62, total time: 855.8692898750305
# completed LL63, total time: 1077.993007183075
# Failed on LL64, md 1, rundle ['R', 'Metro', 2], url: https://www.learnedleague.com/match.php?64&1&R_Metro_Div_2
# completed LL64, total time: 1279.688807964325
# completed LL65, total time: 1459.09517288208
# Failed on LL66, md 3, rundle ['E', 'Horizon', 3], url: https://www.learnedleague.com/match.php?66&3&E_Horizon_Div_3
# Failed on LL66, md 3, rundle ['R', 'Horizon', 1], url: https://www.learnedleague.com/match.php?66&3&R_Horizon_Div_1
# Failed on LL66, md 3, rundle ['R', 'Horizon', 2], url: https://www.learnedleague.com/match.php?66&3&R_Horizon_Div_2
# Failed on LL66, md 3, rundle ['A', 'Maritime', 0], url: https://www.learnedleague.com/match.php?66&3&A_Maritime
# Failed on LL66, md 3, rundle ['B', 'Maritime', 0], url: https://www.learnedleague.com/match.php?66&3&B_Maritime
# Failed on LL66, md 3, rundle ['C', 'Maritime', 1], url: https://www.learnedleague.com/match.php?66&3&C_Maritime_Div_1
# Failed on LL66, md 3, rundle ['C', 'Maritime', 2], url: https://www.learnedleague.com/match.php?66&3&C_Maritime_Div_2
# Failed on LL66, md 3, rundle ['D', 'Maritime', 1], url: https://www.learnedleague.com/match.php?66&3&D_Maritime_Div_1
# Failed on LL66, md 3, rundle ['D', 'Maritime', 2], url: https://www.learnedleague.com/match.php?66&3&D_Maritime_Div_2
# Failed on LL66, md 3, rundle ['E', 'Maritime', 1], url: https://www.learnedleague.com/match.php?66&3&E_Maritime_Div_1
# Failed on LL66, md 3, rundle ['E', 'Maritime', 2], url: https://www.learnedleague.com/match.php?66&3&E_Maritime_Div_2
# Failed on LL66, md 3, rundle ['R', 'Maritime', 1], url: https://www.learnedleague.com/match.php?66&3&R_Maritime_Div_1
# Failed on LL66, md 3, rundle ['R', 'Maritime', 2], url: https://www.learnedleague.com/match.php?66&3&R_Maritime_Div_2
# Failed on LL66, md 3, rundle ['A', 'Memorial', 0], url: https://www.learnedleague.com/match.php?66&3&A_Memorial
# Failed on LL66, md 3, rundle ['B', 'Memorial', 0], url: https://www.learnedleague.com/match.php?66&3&B_Memorial
# Failed on LL66, md 3, rundle ['C', 'Memorial', 0], url: https://www.learnedleague.com/match.php?66&3&C_Memorial
# Failed on LL66, md 3, rundle ['D', 'Memorial', 1], url: https://www.learnedleague.com/match.php?66&3&D_Memorial_Div_1
# Failed on LL66, md 3, rundle ['D', 'Memorial', 2], url: https://www.learnedleague.com/match.php?66&3&D_Memorial_Div_2
# Failed on LL66, md 3, rundle ['E', 'Memorial', 1], url: https://www.learnedleague.com/match.php?66&3&E_Memorial_Div_1
# Failed on LL66, md 3, rundle ['E', 'Memorial', 2], url: https://www.learnedleague.com/match.php?66&3&E_Memorial_Div_2
# Failed on LL66, md 3, rundle ['R', 'Memorial', 1], url: https://www.learnedleague.com/match.php?66&3&R_Memorial_Div_1
# Failed on LL66, md 3, rundle ['R', 'Memorial', 2], url: https://www.learnedleague.com/match.php?66&3&R_Memorial_Div_2
# Failed on LL66, md 3, rundle ['A', 'Meridian', 0], url: https://www.learnedleague.com/match.php?66&3&A_Meridian
# Failed on LL66, md 3, rundle ['B', 'Meridian', 0], url: https://www.learnedleague.com/match.php?66&3&B_Meridian
# Failed on LL66, md 3, rundle ['C', 'Meridian', 1], url: https://www.learnedleague.com/match.php?66&3&C_Meridian_Div_1
# Failed on LL66, md 3, rundle ['C', 'Meridian', 2], url: https://www.learnedleague.com/match.php?66&3&C_Meridian_Div_2
# Failed on LL66, md 3, rundle ['D', 'Meridian', 1], url: https://www.learnedleague.com/match.php?66&3&D_Meridian_Div_1
# Failed on LL66, md 3, rundle ['D', 'Meridian', 2], url: https://www.learnedleague.com/match.php?66&3&D_Meridian_Div_2
# Failed on LL66, md 3, rundle ['E', 'Meridian', 1], url: https://www.learnedleague.com/match.php?66&3&E_Meridian_Div_1
# Failed on LL66, md 3, rundle ['E', 'Meridian', 2], url: https://www.learnedleague.com/match.php?66&3&E_Meridian_Div_2
# Failed on LL66, md 3, rundle ['R', 'Meridian', 1], url: https://www.learnedleague.com/match.php?66&3&R_Meridian_Div_1
# Failed on LL66, md 3, rundle ['R', 'Meridian', 2], url: https://www.learnedleague.com/match.php?66&3&R_Meridian_Div_2
# Failed on LL66, md 3, rundle ['A', 'Metro', 0], url: https://www.learnedleague.com/match.php?66&3&A_Metro
# Failed on LL66, md 3, rundle ['B', 'Metro', 0], url: https://www.learnedleague.com/match.php?66&3&B_Metro
# Failed on LL66, md 3, rundle ['C', 'Metro', 0], url: https://www.learnedleague.com/match.php?66&3&C_Metro
# Failed on LL66, md 3, rundle ['D', 'Metro', 1], url: https://www.learnedleague.com/match.php?66&3&D_Metro_Div_1
# Failed on LL66, md 3, rundle ['D', 'Metro', 2], url: https://www.learnedleague.com/match.php?66&3&D_Metro_Div_2
# Failed on LL66, md 3, rundle ['E', 'Metro', 1], url: https://www.learnedleague.com/match.php?66&3&E_Metro_Div_1
# Failed on LL66, md 3, rundle ['E', 'Metro', 2], url: https://www.learnedleague.com/match.php?66&3&E_Metro_Div_2
# Failed on LL66, md 3, rundle ['R', 'Metro', 1], url: https://www.learnedleague.com/match.php?66&3&R_Metro_Div_1
# Failed on LL66, md 3, rundle ['R', 'Metro', 2], url: https://www.learnedleague.com/match.php?66&3&R_Metro_Div_2
# Failed on LL66, md 3, rundle ['A', 'Midland', 0], url: https://www.learnedleague.com/match.php?66&3&A_Midland
# Failed on LL66, md 3, rundle ['B', 'Midland', 0], url: https://www.learnedleague.com/match.php?66&3&B_Midland
# Failed on LL66, md 3, rundle ['C', 'Midland', 1], url: https://www.learnedleague.com/match.php?66&3&C_Midland_Div_1
# Failed on LL66, md 3, rundle ['C', 'Midland', 2], url: https://www.learnedleague.com/match.php?66&3&C_Midland_Div_2
# Failed on LL66, md 3, rundle ['D', 'Midland', 1], url: https://www.learnedleague.com/match.php?66&3&D_Midland_Div_1
# Failed on LL66, md 3, rundle ['D', 'Midland', 2], url: https://www.learnedleague.com/match.php?66&3&D_Midland_Div_2
# Failed on LL66, md 3, rundle ['E', 'Midland', 1], url: https://www.learnedleague.com/match.php?66&3&E_Midland_Div_1
# Failed on LL66, md 3, rundle ['E', 'Midland', 2], url: https://www.learnedleague.com/match.php?66&3&E_Midland_Div_2
# Failed on LL66, md 3, rundle ['R', 'Midland', 1], url: https://www.learnedleague.com/match.php?66&3&R_Midland_Div_1
# Failed on LL66, md 3, rundle ['R', 'Midland', 2], url: https://www.learnedleague.com/match.php?66&3&R_Midland_Div_2
# Failed on LL66, md 3, rundle ['A', 'Pacific', 0], url: https://www.learnedleague.com/match.php?66&3&A_Pacific
# Failed on LL66, md 3, rundle ['B', 'Pacific', 0], url: https://www.learnedleague.com/match.php?66&3&B_Pacific
# Failed on LL66, md 3, rundle ['C', 'Pacific', 1], url: https://www.learnedleague.com/match.php?66&3&C_Pacific_Div_1
# Failed on LL66, md 3, rundle ['C', 'Pacific', 2], url: https://www.learnedleague.com/match.php?66&3&C_Pacific_Div_2
# Failed on LL66, md 3, rundle ['D', 'Pacific', 1], url: https://www.learnedleague.com/match.php?66&3&D_Pacific_Div_1
# Failed on LL66, md 3, rundle ['D', 'Pacific', 2], url: https://www.learnedleague.com/match.php?66&3&D_Pacific_Div_2
# Failed on LL66, md 3, rundle ['E', 'Pacific', 1], url: https://www.learnedleague.com/match.php?66&3&E_Pacific_Div_1
# Failed on LL66, md 3, rundle ['E', 'Pacific', 2], url: https://www.learnedleague.com/match.php?66&3&E_Pacific_Div_2
# Failed on LL66, md 3, rundle ['R', 'Pacific', 1], url: https://www.learnedleague.com/match.php?66&3&R_Pacific_Div_1
# Failed on LL66, md 3, rundle ['R', 'Pacific', 2], url: https://www.learnedleague.com/match.php?66&3&R_Pacific_Div_2
# Failed on LL66, md 3, rundle ['A', 'Seaboard', 0], url: https://www.learnedleague.com/match.php?66&3&A_Seaboard
# Failed on LL66, md 3, rundle ['B', 'Seaboard', 0], url: https://www.learnedleague.com/match.php?66&3&B_Seaboard
# Failed on LL66, md 3, rundle ['C', 'Seaboard', 1], url: https://www.learnedleague.com/match.php?66&3&C_Seaboard_Div_1
# Failed on LL66, md 3, rundle ['C', 'Seaboard', 2], url: https://www.learnedleague.com/match.php?66&3&C_Seaboard_Div_2
# Failed on LL66, md 3, rundle ['D', 'Seaboard', 1], url: https://www.learnedleague.com/match.php?66&3&D_Seaboard_Div_1
# Failed on LL66, md 3, rundle ['D', 'Seaboard', 2], url: https://www.learnedleague.com/match.php?66&3&D_Seaboard_Div_2
# Failed on LL66, md 3, rundle ['E', 'Seaboard', 1], url: https://www.learnedleague.com/match.php?66&3&E_Seaboard_Div_1
# Failed on LL66, md 3, rundle ['E', 'Seaboard', 2], url: https://www.learnedleague.com/match.php?66&3&E_Seaboard_Div_2
# Failed on LL66, md 3, rundle ['R', 'Seaboard', 1], url: https://www.learnedleague.com/match.php?66&3&R_Seaboard_Div_1
# Failed on LL66, md 3, rundle ['R', 'Seaboard', 2], url: https://www.learnedleague.com/match.php?66&3&R_Seaboard_Div_2
# Failed on LL66, md 3, rundle ['A', 'Sequoia', 0], url: https://www.learnedleague.com/match.php?66&3&A_Sequoia
# Failed on LL66, md 3, rundle ['B', 'Sequoia', 0], url: https://www.learnedleague.com/match.php?66&3&B_Sequoia
# Failed on LL66, md 3, rundle ['C', 'Sequoia', 1], url: https://www.learnedleague.com/match.php?66&3&C_Sequoia_Div_1
# Failed on LL66, md 3, rundle ['C', 'Sequoia', 2], url: https://www.learnedleague.com/match.php?66&3&C_Sequoia_Div_2
# Failed on LL66, md 3, rundle ['D', 'Sequoia', 1], url: https://www.learnedleague.com/match.php?66&3&D_Sequoia_Div_1
# Failed on LL66, md 3, rundle ['D', 'Sequoia', 2], url: https://www.learnedleague.com/match.php?66&3&D_Sequoia_Div_2
# Failed on LL66, md 3, rundle ['E', 'Sequoia', 1], url: https://www.learnedleague.com/match.php?66&3&E_Sequoia_Div_1
# Failed on LL66, md 3, rundle ['E', 'Sequoia', 2], url: https://www.learnedleague.com/match.php?66&3&E_Sequoia_Div_2
# Failed on LL66, md 3, rundle ['R', 'Sequoia', 1], url: https://www.learnedleague.com/match.php?66&3&R_Sequoia_Div_1
# Failed on LL66, md 3, rundle ['R', 'Sequoia', 2], url: https://www.learnedleague.com/match.php?66&3&R_Sequoia_Div_2
# Failed on LL66, md 3, rundle ['A', 'Skyline', 0], url: https://www.learnedleague.com/match.php?66&3&A_Skyline
# Failed on LL66, md 3, rundle ['B', 'Skyline', 0], url: https://www.learnedleague.com/match.php?66&3&B_Skyline
# Failed on LL66, md 3, rundle ['C', 'Skyline', 1], url: https://www.learnedleague.com/match.php?66&3&C_Skyline_Div_1
# Failed on LL66, md 3, rundle ['C', 'Skyline', 2], url: https://www.learnedleague.com/match.php?66&3&C_Skyline_Div_2
# Failed on LL66, md 3, rundle ['D', 'Skyline', 1], url: https://www.learnedleague.com/match.php?66&3&D_Skyline_Div_1
# Failed on LL66, md 3, rundle ['D', 'Skyline', 2], url: https://www.learnedleague.com/match.php?66&3&D_Skyline_Div_2
# Failed on LL66, md 3, rundle ['E', 'Skyline', 1], url: https://www.learnedleague.com/match.php?66&3&E_Skyline_Div_1
# Failed on LL66, md 3, rundle ['E', 'Skyline', 2], url: https://www.learnedleague.com/match.php?66&3&E_Skyline_Div_2
# Failed on LL66, md 3, rundle ['R', 'Skyline', 1], url: https://www.learnedleague.com/match.php?66&3&R_Skyline_Div_1
# Failed on LL66, md 3, rundle ['R', 'Skyline', 2], url: https://www.learnedleague.com/match.php?66&3&R_Skyline_Div_2
# Failed on LL66, md 3, rundle ['A', 'Sugarloaf', 0], url: https://www.learnedleague.com/match.php?66&3&A_Sugarloaf
# Failed on LL66, md 3, rundle ['B', 'Sugarloaf', 0], url: https://www.learnedleague.com/match.php?66&3&B_Sugarloaf
# Failed on LL66, md 3, rundle ['C', 'Sugarloaf', 0], url: https://www.learnedleague.com/match.php?66&3&C_Sugarloaf
# Failed on LL66, md 3, rundle ['D', 'Sugarloaf', 1], url: https://www.learnedleague.com/match.php?66&3&D_Sugarloaf_Div_1
# Failed on LL66, md 3, rundle ['D', 'Sugarloaf', 2], url: https://www.learnedleague.com/match.php?66&3&D_Sugarloaf_Div_2
# Failed on LL66, md 3, rundle ['E', 'Sugarloaf', 1], url: https://www.learnedleague.com/match.php?66&3&E_Sugarloaf_Div_1
# Failed on LL66, md 3, rundle ['E', 'Sugarloaf', 2], url: https://www.learnedleague.com/match.php?66&3&E_Sugarloaf_Div_2
# Failed on LL66, md 3, rundle ['R', 'Sugarloaf', 1], url: https://www.learnedleague.com/match.php?66&3&R_Sugarloaf_Div_1
# Failed on LL66, md 3, rundle ['R', 'Sugarloaf', 2], url: https://www.learnedleague.com/match.php?66&3&R_Sugarloaf_Div_2
# Failed on LL66, md 4, rundle ['A', 'Alpine', 0], url: https://www.learnedleague.com/match.php?66&4&A_Alpine
# Failed on LL66, md 4, rundle ['B', 'Alpine', 0], url: https://www.learnedleague.com/match.php?66&4&B_Alpine
# Failed on LL66, md 4, rundle ['C', 'Alpine', 0], url: https://www.learnedleague.com/match.php?66&4&C_Alpine
# Failed on LL66, md 4, rundle ['D', 'Alpine', 1], url: https://www.learnedleague.com/match.php?66&4&D_Alpine_Div_1
# Failed on LL66, md 4, rundle ['D', 'Alpine', 2], url: https://www.learnedleague.com/match.php?66&4&D_Alpine_Div_2
# Failed on LL66, md 4, rundle ['E', 'Alpine', 1], url: https://www.learnedleague.com/match.php?66&4&E_Alpine_Div_1
# Failed on LL66, md 4, rundle ['E', 'Alpine', 2], url: https://www.learnedleague.com/match.php?66&4&E_Alpine_Div_2
# Failed on LL66, md 4, rundle ['R', 'Alpine', 1], url: https://www.learnedleague.com/match.php?66&4&R_Alpine_Div_1
# Failed on LL66, md 4, rundle ['R', 'Alpine', 2], url: https://www.learnedleague.com/match.php?66&4&R_Alpine_Div_2
# Failed on LL66, md 4, rundle ['A', 'Central', 0], url: https://www.learnedleague.com/match.php?66&4&A_Central
# Failed on LL66, md 4, rundle ['B', 'Central', 0], url: https://www.learnedleague.com/match.php?66&4&B_Central
# Failed on LL66, md 4, rundle ['C', 'Central', 0], url: https://www.learnedleague.com/match.php?66&4&C_Central
# Failed on LL66, md 4, rundle ['D', 'Central', 1], url: https://www.learnedleague.com/match.php?66&4&D_Central_Div_1
# Failed on LL66, md 4, rundle ['D', 'Central', 2], url: https://www.learnedleague.com/match.php?66&4&D_Central_Div_2
# Failed on LL66, md 4, rundle ['E', 'Central', 1], url: https://www.learnedleague.com/match.php?66&4&E_Central_Div_1
# Failed on LL66, md 4, rundle ['E', 'Central', 2], url: https://www.learnedleague.com/match.php?66&4&E_Central_Div_2
# Failed on LL66, md 4, rundle ['R', 'Central', 1], url: https://www.learnedleague.com/match.php?66&4&R_Central_Div_1
# Failed on LL66, md 4, rundle ['R', 'Central', 2], url: https://www.learnedleague.com/match.php?66&4&R_Central_Div_2
# Failed on LL66, md 4, rundle ['A', 'Coastal', 0], url: https://www.learnedleague.com/match.php?66&4&A_Coastal
# Failed on LL66, md 4, rundle ['B', 'Coastal', 0], url: https://www.learnedleague.com/match.php?66&4&B_Coastal
# Failed on LL66, md 4, rundle ['C', 'Coastal', 0], url: https://www.learnedleague.com/match.php?66&4&C_Coastal
# Failed on LL66, md 4, rundle ['D', 'Coastal', 1], url: https://www.learnedleague.com/match.php?66&4&D_Coastal_Div_1
# Failed on LL66, md 4, rundle ['D', 'Coastal', 2], url: https://www.learnedleague.com/match.php?66&4&D_Coastal_Div_2
# Failed on LL66, md 4, rundle ['E', 'Coastal', 1], url: https://www.learnedleague.com/match.php?66&4&E_Coastal_Div_1
# Failed on LL66, md 4, rundle ['E', 'Coastal', 2], url: https://www.learnedleague.com/match.php?66&4&E_Coastal_Div_2
# Failed on LL66, md 4, rundle ['R', 'Coastal', 1], url: https://www.learnedleague.com/match.php?66&4&R_Coastal_Div_1
# Failed on LL66, md 4, rundle ['R', 'Coastal', 2], url: https://www.learnedleague.com/match.php?66&4&R_Coastal_Div_2
# Failed on LL66, md 4, rundle ['A', 'Corridor', 0], url: https://www.learnedleague.com/match.php?66&4&A_Corridor
# Failed on LL66, md 4, rundle ['B', 'Corridor', 0], url: https://www.learnedleague.com/match.php?66&4&B_Corridor
# Failed on LL66, md 4, rundle ['C', 'Corridor', 0], url: https://www.learnedleague.com/match.php?66&4&C_Corridor
# Failed on LL66, md 4, rundle ['D', 'Corridor', 1], url: https://www.learnedleague.com/match.php?66&4&D_Corridor_Div_1
# Failed on LL66, md 4, rundle ['D', 'Corridor', 2], url: https://www.learnedleague.com/match.php?66&4&D_Corridor_Div_2
# Failed on LL66, md 4, rundle ['E', 'Corridor', 1], url: https://www.learnedleague.com/match.php?66&4&E_Corridor_Div_1
# Failed on LL66, md 4, rundle ['E', 'Corridor', 2], url: https://www.learnedleague.com/match.php?66&4&E_Corridor_Div_2
# Failed on LL66, md 4, rundle ['R', 'Corridor', 1], url: https://www.learnedleague.com/match.php?66&4&R_Corridor_Div_1
# Failed on LL66, md 4, rundle ['R', 'Corridor', 2], url: https://www.learnedleague.com/match.php?66&4&R_Corridor_Div_2
# Failed on LL66, md 4, rundle ['A', 'Frontier', 0], url: https://www.learnedleague.com/match.php?66&4&A_Frontier
# Failed on LL66, md 4, rundle ['B', 'Frontier', 0], url: https://www.learnedleague.com/match.php?66&4&B_Frontier
# Failed on LL66, md 4, rundle ['C', 'Frontier', 0], url: https://www.learnedleague.com/match.php?66&4&C_Frontier
# Failed on LL66, md 4, rundle ['D', 'Frontier', 1], url: https://www.learnedleague.com/match.php?66&4&D_Frontier_Div_1
# Failed on LL66, md 4, rundle ['D', 'Frontier', 2], url: https://www.learnedleague.com/match.php?66&4&D_Frontier_Div_2
# Failed on LL66, md 4, rundle ['E', 'Frontier', 1], url: https://www.learnedleague.com/match.php?66&4&E_Frontier_Div_1
# Failed on LL66, md 4, rundle ['E', 'Frontier', 2], url: https://www.learnedleague.com/match.php?66&4&E_Frontier_Div_2
# Failed on LL66, md 4, rundle ['R', 'Frontier', 1], url: https://www.learnedleague.com/match.php?66&4&R_Frontier_Div_1
# Failed on LL66, md 4, rundle ['R', 'Frontier', 2], url: https://www.learnedleague.com/match.php?66&4&R_Frontier_Div_2
# Failed on LL66, md 4, rundle ['A', 'Highland', 0], url: https://www.learnedleague.com/match.php?66&4&A_Highland
# Failed on LL66, md 4, rundle ['B', 'Highland', 0], url: https://www.learnedleague.com/match.php?66&4&B_Highland
# Failed on LL66, md 4, rundle ['C', 'Highland', 0], url: https://www.learnedleague.com/match.php?66&4&C_Highland
# Failed on LL66, md 4, rundle ['D', 'Highland', 1], url: https://www.learnedleague.com/match.php?66&4&D_Highland_Div_1
# Failed on LL66, md 4, rundle ['D', 'Highland', 2], url: https://www.learnedleague.com/match.php?66&4&D_Highland_Div_2
# Failed on LL66, md 4, rundle ['E', 'Highland', 1], url: https://www.learnedleague.com/match.php?66&4&E_Highland_Div_1
# Failed on LL66, md 4, rundle ['E', 'Highland', 2], url: https://www.learnedleague.com/match.php?66&4&E_Highland_Div_2
# Failed on LL66, md 4, rundle ['R', 'Highland', 1], url: https://www.learnedleague.com/match.php?66&4&R_Highland_Div_1
# Failed on LL66, md 4, rundle ['R', 'Highland', 2], url: https://www.learnedleague.com/match.php?66&4&R_Highland_Div_2
# Failed on LL66, md 4, rundle ['A', 'Horizon', 0], url: https://www.learnedleague.com/match.php?66&4&A_Horizon
# Failed on LL66, md 4, rundle ['B', 'Horizon', 0], url: https://www.learnedleague.com/match.php?66&4&B_Horizon
# Failed on LL66, md 4, rundle ['C', 'Horizon', 1], url: https://www.learnedleague.com/match.php?66&4&C_Horizon_Div_1
# Failed on LL66, md 4, rundle ['C', 'Horizon', 2], url: https://www.learnedleague.com/match.php?66&4&C_Horizon_Div_2
# Failed on LL66, md 4, rundle ['D', 'Horizon', 1], url: https://www.learnedleague.com/match.php?66&4&D_Horizon_Div_1
# Failed on LL66, md 4, rundle ['D', 'Horizon', 2], url: https://www.learnedleague.com/match.php?66&4&D_Horizon_Div_2
# Failed on LL66, md 4, rundle ['D', 'Horizon', 3], url: https://www.learnedleague.com/match.php?66&4&D_Horizon_Div_3
# Failed on LL66, md 4, rundle ['E', 'Horizon', 1], url: https://www.learnedleague.com/match.php?66&4&E_Horizon_Div_1
# Failed on LL66, md 4, rundle ['E', 'Horizon', 2], url: https://www.learnedleague.com/match.php?66&4&E_Horizon_Div_2
# Failed on LL66, md 4, rundle ['E', 'Horizon', 3], url: https://www.learnedleague.com/match.php?66&4&E_Horizon_Div_3
# Failed on LL66, md 4, rundle ['R', 'Horizon', 1], url: https://www.learnedleague.com/match.php?66&4&R_Horizon_Div_1
# Failed on LL66, md 4, rundle ['R', 'Horizon', 2], url: https://www.learnedleague.com/match.php?66&4&R_Horizon_Div_2
# Failed on LL66, md 4, rundle ['A', 'Maritime', 0], url: https://www.learnedleague.com/match.php?66&4&A_Maritime
# Failed on LL66, md 4, rundle ['B', 'Maritime', 0], url: https://www.learnedleague.com/match.php?66&4&B_Maritime
# Failed on LL66, md 4, rundle ['C', 'Maritime', 1], url: https://www.learnedleague.com/match.php?66&4&C_Maritime_Div_1
# Failed on LL66, md 4, rundle ['C', 'Maritime', 2], url: https://www.learnedleague.com/match.php?66&4&C_Maritime_Div_2
# Failed on LL66, md 4, rundle ['D', 'Maritime', 1], url: https://www.learnedleague.com/match.php?66&4&D_Maritime_Div_1
# Failed on LL66, md 4, rundle ['D', 'Maritime', 2], url: https://www.learnedleague.com/match.php?66&4&D_Maritime_Div_2
# Failed on LL66, md 4, rundle ['E', 'Maritime', 1], url: https://www.learnedleague.com/match.php?66&4&E_Maritime_Div_1
# Failed on LL66, md 4, rundle ['E', 'Maritime', 2], url: https://www.learnedleague.com/match.php?66&4&E_Maritime_Div_2
# Failed on LL66, md 4, rundle ['R', 'Maritime', 1], url: https://www.learnedleague.com/match.php?66&4&R_Maritime_Div_1
# Failed on LL66, md 4, rundle ['R', 'Maritime', 2], url: https://www.learnedleague.com/match.php?66&4&R_Maritime_Div_2
# Failed on LL66, md 4, rundle ['A', 'Memorial', 0], url: https://www.learnedleague.com/match.php?66&4&A_Memorial
# Failed on LL66, md 4, rundle ['B', 'Memorial', 0], url: https://www.learnedleague.com/match.php?66&4&B_Memorial
# Failed on LL66, md 4, rundle ['C', 'Memorial', 0], url: https://www.learnedleague.com/match.php?66&4&C_Memorial
# Failed on LL66, md 4, rundle ['D', 'Memorial', 1], url: https://www.learnedleague.com/match.php?66&4&D_Memorial_Div_1
# Failed on LL66, md 4, rundle ['D', 'Memorial', 2], url: https://www.learnedleague.com/match.php?66&4&D_Memorial_Div_2
# Failed on LL66, md 4, rundle ['E', 'Memorial', 1], url: https://www.learnedleague.com/match.php?66&4&E_Memorial_Div_1
# Failed on LL66, md 4, rundle ['E', 'Memorial', 2], url: https://www.learnedleague.com/match.php?66&4&E_Memorial_Div_2
# Failed on LL66, md 4, rundle ['R', 'Memorial', 1], url: https://www.learnedleague.com/match.php?66&4&R_Memorial_Div_1
# Failed on LL66, md 4, rundle ['R', 'Memorial', 2], url: https://www.learnedleague.com/match.php?66&4&R_Memorial_Div_2
# Failed on LL66, md 4, rundle ['A', 'Meridian', 0], url: https://www.learnedleague.com/match.php?66&4&A_Meridian
# Failed on LL66, md 4, rundle ['B', 'Meridian', 0], url: https://www.learnedleague.com/match.php?66&4&B_Meridian
# Failed on LL66, md 4, rundle ['C', 'Meridian', 1], url: https://www.learnedleague.com/match.php?66&4&C_Meridian_Div_1
# Failed on LL66, md 4, rundle ['C', 'Meridian', 2], url: https://www.learnedleague.com/match.php?66&4&C_Meridian_Div_2
# Failed on LL66, md 4, rundle ['D', 'Meridian', 1], url: https://www.learnedleague.com/match.php?66&4&D_Meridian_Div_1
# Failed on LL66, md 4, rundle ['D', 'Meridian', 2], url: https://www.learnedleague.com/match.php?66&4&D_Meridian_Div_2
# Failed on LL66, md 4, rundle ['E', 'Meridian', 1], url: https://www.learnedleague.com/match.php?66&4&E_Meridian_Div_1
# Failed on LL66, md 4, rundle ['E', 'Meridian', 2], url: https://www.learnedleague.com/match.php?66&4&E_Meridian_Div_2
# Failed on LL66, md 4, rundle ['R', 'Meridian', 1], url: https://www.learnedleague.com/match.php?66&4&R_Meridian_Div_1
# Failed on LL66, md 4, rundle ['R', 'Meridian', 2], url: https://www.learnedleague.com/match.php?66&4&R_Meridian_Div_2
# Failed on LL66, md 4, rundle ['A', 'Metro', 0], url: https://www.learnedleague.com/match.php?66&4&A_Metro
# Failed on LL66, md 4, rundle ['B', 'Metro', 0], url: https://www.learnedleague.com/match.php?66&4&B_Metro
# Failed on LL66, md 4, rundle ['C', 'Metro', 0], url: https://www.learnedleague.com/match.php?66&4&C_Metro
# Failed on LL66, md 4, rundle ['D', 'Metro', 1], url: https://www.learnedleague.com/match.php?66&4&D_Metro_Div_1
# Failed on LL66, md 4, rundle ['D', 'Metro', 2], url: https://www.learnedleague.com/match.php?66&4&D_Metro_Div_2
# Failed on LL66, md 4, rundle ['E', 'Metro', 1], url: https://www.learnedleague.com/match.php?66&4&E_Metro_Div_1
# Failed on LL66, md 4, rundle ['E', 'Metro', 2], url: https://www.learnedleague.com/match.php?66&4&E_Metro_Div_2
# Failed on LL66, md 4, rundle ['R', 'Metro', 1], url: https://www.learnedleague.com/match.php?66&4&R_Metro_Div_1
# Failed on LL66, md 4, rundle ['R', 'Metro', 2], url: https://www.learnedleague.com/match.php?66&4&R_Metro_Div_2
# Failed on LL66, md 4, rundle ['A', 'Midland', 0], url: https://www.learnedleague.com/match.php?66&4&A_Midland
# Failed on LL66, md 4, rundle ['B', 'Midland', 0], url: https://www.learnedleague.com/match.php?66&4&B_Midland
# Failed on LL66, md 4, rundle ['C', 'Midland', 1], url: https://www.learnedleague.com/match.php?66&4&C_Midland_Div_1
# Failed on LL66, md 4, rundle ['C', 'Midland', 2], url: https://www.learnedleague.com/match.php?66&4&C_Midland_Div_2
# Failed on LL66, md 4, rundle ['D', 'Midland', 1], url: https://www.learnedleague.com/match.php?66&4&D_Midland_Div_1
# Failed on LL66, md 4, rundle ['D', 'Midland', 2], url: https://www.learnedleague.com/match.php?66&4&D_Midland_Div_2
# Failed on LL66, md 4, rundle ['E', 'Midland', 1], url: https://www.learnedleague.com/match.php?66&4&E_Midland_Div_1
# Failed on LL66, md 4, rundle ['E', 'Midland', 2], url: https://www.learnedleague.com/match.php?66&4&E_Midland_Div_2
# Failed on LL66, md 4, rundle ['R', 'Midland', 1], url: https://www.learnedleague.com/match.php?66&4&R_Midland_Div_1
# Failed on LL66, md 4, rundle ['R', 'Midland', 2], url: https://www.learnedleague.com/match.php?66&4&R_Midland_Div_2
# Failed on LL66, md 4, rundle ['A', 'Pacific', 0], url: https://www.learnedleague.com/match.php?66&4&A_Pacific
# Failed on LL66, md 4, rundle ['B', 'Pacific', 0], url: https://www.learnedleague.com/match.php?66&4&B_Pacific
# Failed on LL66, md 4, rundle ['C', 'Pacific', 1], url: https://www.learnedleague.com/match.php?66&4&C_Pacific_Div_1
# Failed on LL66, md 4, rundle ['C', 'Pacific', 2], url: https://www.learnedleague.com/match.php?66&4&C_Pacific_Div_2
# Failed on LL66, md 4, rundle ['D', 'Pacific', 1], url: https://www.learnedleague.com/match.php?66&4&D_Pacific_Div_1
# Failed on LL66, md 4, rundle ['D', 'Pacific', 2], url: https://www.learnedleague.com/match.php?66&4&D_Pacific_Div_2
# Failed on LL66, md 4, rundle ['E', 'Pacific', 1], url: https://www.learnedleague.com/match.php?66&4&E_Pacific_Div_1
# Failed on LL66, md 4, rundle ['E', 'Pacific', 2], url: https://www.learnedleague.com/match.php?66&4&E_Pacific_Div_2
# Failed on LL66, md 4, rundle ['R', 'Pacific', 1], url: https://www.learnedleague.com/match.php?66&4&R_Pacific_Div_1
# Failed on LL66, md 4, rundle ['R', 'Pacific', 2], url: https://www.learnedleague.com/match.php?66&4&R_Pacific_Div_2
# Failed on LL66, md 4, rundle ['A', 'Seaboard', 0], url: https://www.learnedleague.com/match.php?66&4&A_Seaboard
# Failed on LL66, md 4, rundle ['B', 'Seaboard', 0], url: https://www.learnedleague.com/match.php?66&4&B_Seaboard
# Failed on LL66, md 4, rundle ['C', 'Seaboard', 1], url: https://www.learnedleague.com/match.php?66&4&C_Seaboard_Div_1
# Failed on LL66, md 4, rundle ['C', 'Seaboard', 2], url: https://www.learnedleague.com/match.php?66&4&C_Seaboard_Div_2
# Failed on LL66, md 4, rundle ['D', 'Seaboard', 1], url: https://www.learnedleague.com/match.php?66&4&D_Seaboard_Div_1
# Failed on LL66, md 4, rundle ['D', 'Seaboard', 2], url: https://www.learnedleague.com/match.php?66&4&D_Seaboard_Div_2
# Failed on LL66, md 4, rundle ['E', 'Seaboard', 1], url: https://www.learnedleague.com/match.php?66&4&E_Seaboard_Div_1
# Failed on LL66, md 4, rundle ['E', 'Seaboard', 2], url: https://www.learnedleague.com/match.php?66&4&E_Seaboard_Div_2
# Failed on LL66, md 4, rundle ['R', 'Seaboard', 1], url: https://www.learnedleague.com/match.php?66&4&R_Seaboard_Div_1
# Failed on LL66, md 4, rundle ['R', 'Seaboard', 2], url: https://www.learnedleague.com/match.php?66&4&R_Seaboard_Div_2
# Failed on LL66, md 4, rundle ['A', 'Sequoia', 0], url: https://www.learnedleague.com/match.php?66&4&A_Sequoia
# Failed on LL66, md 4, rundle ['B', 'Sequoia', 0], url: https://www.learnedleague.com/match.php?66&4&B_Sequoia
# Failed on LL66, md 4, rundle ['C', 'Sequoia', 1], url: https://www.learnedleague.com/match.php?66&4&C_Sequoia_Div_1
# Failed on LL66, md 4, rundle ['C', 'Sequoia', 2], url: https://www.learnedleague.com/match.php?66&4&C_Sequoia_Div_2
# Failed on LL66, md 4, rundle ['D', 'Sequoia', 1], url: https://www.learnedleague.com/match.php?66&4&D_Sequoia_Div_1
# Failed on LL66, md 4, rundle ['D', 'Sequoia', 2], url: https://www.learnedleague.com/match.php?66&4&D_Sequoia_Div_2
# Failed on LL66, md 4, rundle ['E', 'Sequoia', 1], url: https://www.learnedleague.com/match.php?66&4&E_Sequoia_Div_1
# Failed on LL66, md 4, rundle ['E', 'Sequoia', 2], url: https://www.learnedleague.com/match.php?66&4&E_Sequoia_Div_2
# Failed on LL66, md 4, rundle ['R', 'Sequoia', 1], url: https://www.learnedleague.com/match.php?66&4&R_Sequoia_Div_1
# Failed on LL66, md 4, rundle ['R', 'Sequoia', 2], url: https://www.learnedleague.com/match.php?66&4&R_Sequoia_Div_2
# Failed on LL66, md 4, rundle ['A', 'Skyline', 0], url: https://www.learnedleague.com/match.php?66&4&A_Skyline
# Failed on LL66, md 4, rundle ['B', 'Skyline', 0], url: https://www.learnedleague.com/match.php?66&4&B_Skyline
# Failed on LL66, md 4, rundle ['C', 'Skyline', 1], url: https://www.learnedleague.com/match.php?66&4&C_Skyline_Div_1
# Failed on LL66, md 4, rundle ['C', 'Skyline', 2], url: https://www.learnedleague.com/match.php?66&4&C_Skyline_Div_2
# Failed on LL66, md 4, rundle ['D', 'Skyline', 1], url: https://www.learnedleague.com/match.php?66&4&D_Skyline_Div_1
# Failed on LL66, md 4, rundle ['D', 'Skyline', 2], url: https://www.learnedleague.com/match.php?66&4&D_Skyline_Div_2
# Failed on LL66, md 4, rundle ['E', 'Skyline', 1], url: https://www.learnedleague.com/match.php?66&4&E_Skyline_Div_1
# Failed on LL66, md 4, rundle ['E', 'Skyline', 2], url: https://www.learnedleague.com/match.php?66&4&E_Skyline_Div_2
# Failed on LL66, md 4, rundle ['R', 'Skyline', 1], url: https://www.learnedleague.com/match.php?66&4&R_Skyline_Div_1
# Failed on LL66, md 4, rundle ['R', 'Skyline', 2], url: https://www.learnedleague.com/match.php?66&4&R_Skyline_Div_2
# Failed on LL66, md 4, rundle ['A', 'Sugarloaf', 0], url: https://www.learnedleague.com/match.php?66&4&A_Sugarloaf
# Failed on LL66, md 4, rundle ['B', 'Sugarloaf', 0], url: https://www.learnedleague.com/match.php?66&4&B_Sugarloaf
# Failed on LL66, md 4, rundle ['C', 'Sugarloaf', 0], url: https://www.learnedleague.com/match.php?66&4&C_Sugarloaf
# Failed on LL66, md 4, rundle ['D', 'Sugarloaf', 1], url: https://www.learnedleague.com/match.php?66&4&D_Sugarloaf_Div_1
# Failed on LL66, md 4, rundle ['D', 'Sugarloaf', 2], url: https://www.learnedleague.com/match.php?66&4&D_Sugarloaf_Div_2
# Failed on LL66, md 4, rundle ['E', 'Sugarloaf', 1], url: https://www.learnedleague.com/match.php?66&4&E_Sugarloaf_Div_1
# Failed on LL66, md 4, rundle ['E', 'Sugarloaf', 2], url: https://www.learnedleague.com/match.php?66&4&E_Sugarloaf_Div_2
# Failed on LL66, md 4, rundle ['R', 'Sugarloaf', 1], url: https://www.learnedleague.com/match.php?66&4&R_Sugarloaf_Div_1
# Failed on LL66, md 4, rundle ['R', 'Sugarloaf', 2], url: https://www.learnedleague.com/match.php?66&4&R_Sugarloaf_Div_2
# Failed on LL66, md 5, rundle ['A', 'Alpine', 0], url: https://www.learnedleague.com/match.php?66&5&A_Alpine
# Failed on LL66, md 5, rundle ['B', 'Alpine', 0], url: https://www.learnedleague.com/match.php?66&5&B_Alpine
# Failed on LL66, md 5, rundle ['C', 'Alpine', 0], url: https://www.learnedleague.com/match.php?66&5&C_Alpine
# Failed on LL66, md 5, rundle ['D', 'Alpine', 1], url: https://www.learnedleague.com/match.php?66&5&D_Alpine_Div_1
# Failed on LL66, md 5, rundle ['D', 'Alpine', 2], url: https://www.learnedleague.com/match.php?66&5&D_Alpine_Div_2
# Failed on LL66, md 5, rundle ['E', 'Alpine', 1], url: https://www.learnedleague.com/match.php?66&5&E_Alpine_Div_1
# Failed on LL66, md 5, rundle ['E', 'Alpine', 2], url: https://www.learnedleague.com/match.php?66&5&E_Alpine_Div_2
# Failed on LL66, md 5, rundle ['R', 'Alpine', 1], url: https://www.learnedleague.com/match.php?66&5&R_Alpine_Div_1
# Failed on LL66, md 5, rundle ['R', 'Alpine', 2], url: https://www.learnedleague.com/match.php?66&5&R_Alpine_Div_2
# Failed on LL66, md 5, rundle ['A', 'Central', 0], url: https://www.learnedleague.com/match.php?66&5&A_Central
# Failed on LL66, md 5, rundle ['B', 'Central', 0], url: https://www.learnedleague.com/match.php?66&5&B_Central
# Failed on LL66, md 5, rundle ['C', 'Central', 0], url: https://www.learnedleague.com/match.php?66&5&C_Central
# Failed on LL66, md 5, rundle ['D', 'Central', 1], url: https://www.learnedleague.com/match.php?66&5&D_Central_Div_1
# Failed on LL66, md 5, rundle ['D', 'Central', 2], url: https://www.learnedleague.com/match.php?66&5&D_Central_Div_2
# Failed on LL66, md 5, rundle ['E', 'Central', 1], url: https://www.learnedleague.com/match.php?66&5&E_Central_Div_1
# Failed on LL66, md 5, rundle ['E', 'Central', 2], url: https://www.learnedleague.com/match.php?66&5&E_Central_Div_2
# Failed on LL66, md 5, rundle ['R', 'Central', 1], url: https://www.learnedleague.com/match.php?66&5&R_Central_Div_1
# Failed on LL66, md 5, rundle ['R', 'Central', 2], url: https://www.learnedleague.com/match.php?66&5&R_Central_Div_2
# Failed on LL66, md 5, rundle ['A', 'Coastal', 0], url: https://www.learnedleague.com/match.php?66&5&A_Coastal
# Failed on LL66, md 5, rundle ['B', 'Coastal', 0], url: https://www.learnedleague.com/match.php?66&5&B_Coastal
# Failed on LL66, md 5, rundle ['C', 'Coastal', 0], url: https://www.learnedleague.com/match.php?66&5&C_Coastal
# Failed on LL66, md 5, rundle ['D', 'Coastal', 1], url: https://www.learnedleague.com/match.php?66&5&D_Coastal_Div_1
# Failed on LL66, md 5, rundle ['D', 'Coastal', 2], url: https://www.learnedleague.com/match.php?66&5&D_Coastal_Div_2
# Failed on LL66, md 5, rundle ['E', 'Coastal', 1], url: https://www.learnedleague.com/match.php?66&5&E_Coastal_Div_1
# Failed on LL66, md 5, rundle ['E', 'Coastal', 2], url: https://www.learnedleague.com/match.php?66&5&E_Coastal_Div_2
# Failed on LL66, md 5, rundle ['R', 'Coastal', 1], url: https://www.learnedleague.com/match.php?66&5&R_Coastal_Div_1
# Failed on LL66, md 5, rundle ['R', 'Coastal', 2], url: https://www.learnedleague.com/match.php?66&5&R_Coastal_Div_2
# Failed on LL66, md 5, rundle ['A', 'Corridor', 0], url: https://www.learnedleague.com/match.php?66&5&A_Corridor
# Failed on LL66, md 5, rundle ['B', 'Corridor', 0], url: https://www.learnedleague.com/match.php?66&5&B_Corridor
# Failed on LL66, md 5, rundle ['C', 'Corridor', 0], url: https://www.learnedleague.com/match.php?66&5&C_Corridor
# Failed on LL66, md 5, rundle ['D', 'Corridor', 1], url: https://www.learnedleague.com/match.php?66&5&D_Corridor_Div_1
# Failed on LL66, md 5, rundle ['D', 'Corridor', 2], url: https://www.learnedleague.com/match.php?66&5&D_Corridor_Div_2
# Failed on LL66, md 5, rundle ['E', 'Corridor', 1], url: https://www.learnedleague.com/match.php?66&5&E_Corridor_Div_1
# Failed on LL66, md 5, rundle ['E', 'Corridor', 2], url: https://www.learnedleague.com/match.php?66&5&E_Corridor_Div_2
# Failed on LL66, md 5, rundle ['R', 'Corridor', 1], url: https://www.learnedleague.com/match.php?66&5&R_Corridor_Div_1
# Failed on LL66, md 5, rundle ['R', 'Corridor', 2], url: https://www.learnedleague.com/match.php?66&5&R_Corridor_Div_2
# Failed on LL66, md 5, rundle ['A', 'Frontier', 0], url: https://www.learnedleague.com/match.php?66&5&A_Frontier
# Failed on LL66, md 5, rundle ['B', 'Frontier', 0], url: https://www.learnedleague.com/match.php?66&5&B_Frontier
# Failed on LL66, md 5, rundle ['C', 'Frontier', 0], url: https://www.learnedleague.com/match.php?66&5&C_Frontier
# Failed on LL66, md 5, rundle ['D', 'Frontier', 1], url: https://www.learnedleague.com/match.php?66&5&D_Frontier_Div_1
# Failed on LL66, md 5, rundle ['D', 'Frontier', 2], url: https://www.learnedleague.com/match.php?66&5&D_Frontier_Div_2
# Failed on LL66, md 5, rundle ['E', 'Frontier', 1], url: https://www.learnedleague.com/match.php?66&5&E_Frontier_Div_1
# Failed on LL66, md 5, rundle ['E', 'Frontier', 2], url: https://www.learnedleague.com/match.php?66&5&E_Frontier_Div_2
# Failed on LL66, md 5, rundle ['R', 'Frontier', 1], url: https://www.learnedleague.com/match.php?66&5&R_Frontier_Div_1
# Failed on LL66, md 5, rundle ['R', 'Frontier', 2], url: https://www.learnedleague.com/match.php?66&5&R_Frontier_Div_2
# Failed on LL66, md 5, rundle ['A', 'Highland', 0], url: https://www.learnedleague.com/match.php?66&5&A_Highland
# Failed on LL66, md 5, rundle ['B', 'Highland', 0], url: https://www.learnedleague.com/match.php?66&5&B_Highland
# Failed on LL66, md 5, rundle ['C', 'Highland', 0], url: https://www.learnedleague.com/match.php?66&5&C_Highland
# Failed on LL66, md 5, rundle ['D', 'Highland', 1], url: https://www.learnedleague.com/match.php?66&5&D_Highland_Div_1
# Failed on LL66, md 5, rundle ['D', 'Highland', 2], url: https://www.learnedleague.com/match.php?66&5&D_Highland_Div_2
# Failed on LL66, md 5, rundle ['E', 'Highland', 1], url: https://www.learnedleague.com/match.php?66&5&E_Highland_Div_1
# Failed on LL66, md 5, rundle ['E', 'Highland', 2], url: https://www.learnedleague.com/match.php?66&5&E_Highland_Div_2
# Failed on LL66, md 5, rundle ['R', 'Highland', 1], url: https://www.learnedleague.com/match.php?66&5&R_Highland_Div_1
# Failed on LL66, md 5, rundle ['R', 'Highland', 2], url: https://www.learnedleague.com/match.php?66&5&R_Highland_Div_2
# Failed on LL66, md 5, rundle ['A', 'Horizon', 0], url: https://www.learnedleague.com/match.php?66&5&A_Horizon
# Failed on LL66, md 5, rundle ['B', 'Horizon', 0], url: https://www.learnedleague.com/match.php?66&5&B_Horizon
# Failed on LL66, md 5, rundle ['C', 'Horizon', 1], url: https://www.learnedleague.com/match.php?66&5&C_Horizon_Div_1
# Failed on LL66, md 5, rundle ['C', 'Horizon', 2], url: https://www.learnedleague.com/match.php?66&5&C_Horizon_Div_2
# Failed on LL66, md 5, rundle ['D', 'Horizon', 1], url: https://www.learnedleague.com/match.php?66&5&D_Horizon_Div_1
# Failed on LL66, md 5, rundle ['D', 'Horizon', 2], url: https://www.learnedleague.com/match.php?66&5&D_Horizon_Div_2
# Failed on LL66, md 5, rundle ['D', 'Horizon', 3], url: https://www.learnedleague.com/match.php?66&5&D_Horizon_Div_3
# Failed on LL66, md 5, rundle ['E', 'Horizon', 1], url: https://www.learnedleague.com/match.php?66&5&E_Horizon_Div_1
# Failed on LL66, md 5, rundle ['E', 'Horizon', 2], url: https://www.learnedleague.com/match.php?66&5&E_Horizon_Div_2
# Failed on LL66, md 5, rundle ['E', 'Horizon', 3], url: https://www.learnedleague.com/match.php?66&5&E_Horizon_Div_3
# Failed on LL66, md 5, rundle ['R', 'Horizon', 1], url: https://www.learnedleague.com/match.php?66&5&R_Horizon_Div_1
# Failed on LL66, md 5, rundle ['R', 'Horizon', 2], url: https://www.learnedleague.com/match.php?66&5&R_Horizon_Div_2
# Failed on LL66, md 5, rundle ['A', 'Maritime', 0], url: https://www.learnedleague.com/match.php?66&5&A_Maritime
# Failed on LL66, md 5, rundle ['B', 'Maritime', 0], url: https://www.learnedleague.com/match.php?66&5&B_Maritime
# Failed on LL66, md 5, rundle ['C', 'Maritime', 1], url: https://www.learnedleague.com/match.php?66&5&C_Maritime_Div_1
# Failed on LL66, md 5, rundle ['C', 'Maritime', 2], url: https://www.learnedleague.com/match.php?66&5&C_Maritime_Div_2
# Failed on LL66, md 5, rundle ['D', 'Maritime', 1], url: https://www.learnedleague.com/match.php?66&5&D_Maritime_Div_1
# Failed on LL66, md 5, rundle ['D', 'Maritime', 2], url: https://www.learnedleague.com/match.php?66&5&D_Maritime_Div_2
# Failed on LL66, md 5, rundle ['E', 'Maritime', 1], url: https://www.learnedleague.com/match.php?66&5&E_Maritime_Div_1
# Failed on LL66, md 5, rundle ['E', 'Maritime', 2], url: https://www.learnedleague.com/match.php?66&5&E_Maritime_Div_2
# Failed on LL66, md 5, rundle ['R', 'Maritime', 1], url: https://www.learnedleague.com/match.php?66&5&R_Maritime_Div_1
# Failed on LL66, md 5, rundle ['R', 'Maritime', 2], url: https://www.learnedleague.com/match.php?66&5&R_Maritime_Div_2
# Failed on LL66, md 5, rundle ['A', 'Memorial', 0], url: https://www.learnedleague.com/match.php?66&5&A_Memorial
# Failed on LL66, md 5, rundle ['B', 'Memorial', 0], url: https://www.learnedleague.com/match.php?66&5&B_Memorial
# Failed on LL66, md 5, rundle ['C', 'Memorial', 0], url: https://www.learnedleague.com/match.php?66&5&C_Memorial
# Failed on LL66, md 5, rundle ['D', 'Memorial', 1], url: https://www.learnedleague.com/match.php?66&5&D_Memorial_Div_1
# Failed on LL66, md 5, rundle ['D', 'Memorial', 2], url: https://www.learnedleague.com/match.php?66&5&D_Memorial_Div_2
# Failed on LL66, md 5, rundle ['E', 'Memorial', 1], url: https://www.learnedleague.com/match.php?66&5&E_Memorial_Div_1
# Failed on LL66, md 5, rundle ['E', 'Memorial', 2], url: https://www.learnedleague.com/match.php?66&5&E_Memorial_Div_2
# Failed on LL66, md 5, rundle ['R', 'Memorial', 1], url: https://www.learnedleague.com/match.php?66&5&R_Memorial_Div_1
# Failed on LL66, md 5, rundle ['R', 'Memorial', 2], url: https://www.learnedleague.com/match.php?66&5&R_Memorial_Div_2
# Failed on LL66, md 5, rundle ['A', 'Meridian', 0], url: https://www.learnedleague.com/match.php?66&5&A_Meridian
# Failed on LL66, md 5, rundle ['B', 'Meridian', 0], url: https://www.learnedleague.com/match.php?66&5&B_Meridian
# Failed on LL66, md 5, rundle ['C', 'Meridian', 1], url: https://www.learnedleague.com/match.php?66&5&C_Meridian_Div_1
# Failed on LL66, md 5, rundle ['C', 'Meridian', 2], url: https://www.learnedleague.com/match.php?66&5&C_Meridian_Div_2
# Failed on LL66, md 5, rundle ['D', 'Meridian', 1], url: https://www.learnedleague.com/match.php?66&5&D_Meridian_Div_1
# Failed on LL66, md 5, rundle ['D', 'Meridian', 2], url: https://www.learnedleague.com/match.php?66&5&D_Meridian_Div_2
# Failed on LL66, md 5, rundle ['E', 'Meridian', 1], url: https://www.learnedleague.com/match.php?66&5&E_Meridian_Div_1
# Failed on LL66, md 5, rundle ['E', 'Meridian', 2], url: https://www.learnedleague.com/match.php?66&5&E_Meridian_Div_2
# Failed on LL66, md 5, rundle ['R', 'Meridian', 1], url: https://www.learnedleague.com/match.php?66&5&R_Meridian_Div_1
# Failed on LL66, md 5, rundle ['R', 'Meridian', 2], url: https://www.learnedleague.com/match.php?66&5&R_Meridian_Div_2
# Failed on LL66, md 5, rundle ['A', 'Metro', 0], url: https://www.learnedleague.com/match.php?66&5&A_Metro
# Failed on LL66, md 5, rundle ['B', 'Metro', 0], url: https://www.learnedleague.com/match.php?66&5&B_Metro
# Failed on LL66, md 5, rundle ['C', 'Metro', 0], url: https://www.learnedleague.com/match.php?66&5&C_Metro
# Failed on LL66, md 5, rundle ['D', 'Metro', 1], url: https://www.learnedleague.com/match.php?66&5&D_Metro_Div_1
# Failed on LL66, md 5, rundle ['D', 'Metro', 2], url: https://www.learnedleague.com/match.php?66&5&D_Metro_Div_2
# Failed on LL66, md 5, rundle ['E', 'Metro', 1], url: https://www.learnedleague.com/match.php?66&5&E_Metro_Div_1
# Failed on LL66, md 5, rundle ['E', 'Metro', 2], url: https://www.learnedleague.com/match.php?66&5&E_Metro_Div_2
# Failed on LL66, md 5, rundle ['R', 'Metro', 1], url: https://www.learnedleague.com/match.php?66&5&R_Metro_Div_1
# Failed on LL66, md 5, rundle ['R', 'Metro', 2], url: https://www.learnedleague.com/match.php?66&5&R_Metro_Div_2
# Failed on LL66, md 5, rundle ['A', 'Midland', 0], url: https://www.learnedleague.com/match.php?66&5&A_Midland
# Failed on LL66, md 5, rundle ['B', 'Midland', 0], url: https://www.learnedleague.com/match.php?66&5&B_Midland
# Failed on LL66, md 5, rundle ['C', 'Midland', 1], url: https://www.learnedleague.com/match.php?66&5&C_Midland_Div_1
# Failed on LL66, md 5, rundle ['C', 'Midland', 2], url: https://www.learnedleague.com/match.php?66&5&C_Midland_Div_2
# Failed on LL66, md 5, rundle ['D', 'Midland', 1], url: https://www.learnedleague.com/match.php?66&5&D_Midland_Div_1
# Failed on LL66, md 5, rundle ['D', 'Midland', 2], url: https://www.learnedleague.com/match.php?66&5&D_Midland_Div_2
# Failed on LL66, md 5, rundle ['E', 'Midland', 1], url: https://www.learnedleague.com/match.php?66&5&E_Midland_Div_1
# Failed on LL66, md 5, rundle ['E', 'Midland', 2], url: https://www.learnedleague.com/match.php?66&5&E_Midland_Div_2
# Failed on LL66, md 5, rundle ['R', 'Midland', 1], url: https://www.learnedleague.com/match.php?66&5&R_Midland_Div_1
# Failed on LL66, md 5, rundle ['R', 'Midland', 2], url: https://www.learnedleague.com/match.php?66&5&R_Midland_Div_2
# Failed on LL66, md 5, rundle ['A', 'Pacific', 0], url: https://www.learnedleague.com/match.php?66&5&A_Pacific
# Failed on LL66, md 5, rundle ['B', 'Pacific', 0], url: https://www.learnedleague.com/match.php?66&5&B_Pacific
# Failed on LL66, md 5, rundle ['C', 'Pacific', 1], url: https://www.learnedleague.com/match.php?66&5&C_Pacific_Div_1
# Failed on LL66, md 5, rundle ['C', 'Pacific', 2], url: https://www.learnedleague.com/match.php?66&5&C_Pacific_Div_2
# Failed on LL66, md 5, rundle ['D', 'Pacific', 1], url: https://www.learnedleague.com/match.php?66&5&D_Pacific_Div_1
# Failed on LL66, md 5, rundle ['D', 'Pacific', 2], url: https://www.learnedleague.com/match.php?66&5&D_Pacific_Div_2
# Failed on LL66, md 5, rundle ['E', 'Pacific', 1], url: https://www.learnedleague.com/match.php?66&5&E_Pacific_Div_1
# Failed on LL66, md 5, rundle ['E', 'Pacific', 2], url: https://www.learnedleague.com/match.php?66&5&E_Pacific_Div_2
# Failed on LL66, md 5, rundle ['R', 'Pacific', 1], url: https://www.learnedleague.com/match.php?66&5&R_Pacific_Div_1
# Failed on LL66, md 5, rundle ['R', 'Pacific', 2], url: https://www.learnedleague.com/match.php?66&5&R_Pacific_Div_2
# Failed on LL66, md 5, rundle ['A', 'Seaboard', 0], url: https://www.learnedleague.com/match.php?66&5&A_Seaboard
# Failed on LL66, md 5, rundle ['B', 'Seaboard', 0], url: https://www.learnedleague.com/match.php?66&5&B_Seaboard
# Failed on LL66, md 5, rundle ['C', 'Seaboard', 1], url: https://www.learnedleague.com/match.php?66&5&C_Seaboard_Div_1
# Failed on LL66, md 5, rundle ['C', 'Seaboard', 2], url: https://www.learnedleague.com/match.php?66&5&C_Seaboard_Div_2
# Failed on LL66, md 5, rundle ['D', 'Seaboard', 1], url: https://www.learnedleague.com/match.php?66&5&D_Seaboard_Div_1
# Failed on LL66, md 5, rundle ['D', 'Seaboard', 2], url: https://www.learnedleague.com/match.php?66&5&D_Seaboard_Div_2
# Failed on LL66, md 5, rundle ['E', 'Seaboard', 1], url: https://www.learnedleague.com/match.php?66&5&E_Seaboard_Div_1
# Failed on LL66, md 5, rundle ['E', 'Seaboard', 2], url: https://www.learnedleague.com/match.php?66&5&E_Seaboard_Div_2
# Failed on LL66, md 5, rundle ['R', 'Seaboard', 1], url: https://www.learnedleague.com/match.php?66&5&R_Seaboard_Div_1
# Failed on LL66, md 5, rundle ['R', 'Seaboard', 2], url: https://www.learnedleague.com/match.php?66&5&R_Seaboard_Div_2
# Failed on LL66, md 5, rundle ['A', 'Sequoia', 0], url: https://www.learnedleague.com/match.php?66&5&A_Sequoia
# Failed on LL66, md 5, rundle ['B', 'Sequoia', 0], url: https://www.learnedleague.com/match.php?66&5&B_Sequoia
# ...
# Failed on LL88, md 1, rundle ['D', 'Plaza', 1], url: https://www.learnedleague.com/match.php?88&1&D_Plaza_Div_1
# Failed on LL88, md 1, rundle ['D', 'Plaza', 2], url: https://www.learnedleague.com/match.php?88&1&D_Plaza_Div_2
# Failed on LL88, md 1, rundle ['E', 'Plaza', 1], url: https://www.learnedleague.com/match.php?88&1&E_Plaza_Div_1
# Failed on LL88, md 1, rundle ['E', 'Plaza', 2], url: https://www.learnedleague.com/match.php?88&1&E_Plaza_Div_2
# Failed on LL88, md 1, rundle ['R', 'Plaza', 0], url: https://www.learnedleague.com/match.php?88&1&R_Plaza
# Failed on LL88, md 1, rundle ['A', 'Polaris', 0], url: https://www.learnedleague.com/match.php?88&1&A_Polaris
# Failed on LL88, md 1, rundle ['B', 'Polaris', 0], url: https://www.learnedleague.com/match.php?88&1&B_Polaris
# Failed on LL88, md 1, rundle ['C', 'Polaris', 1], url: https://www.learnedleague.com/match.php?88&1&C_Polaris_Div_1
# Failed on LL88, md 1, rundle ['C', 'Polaris', 2], url: https://www.learnedleague.com/match.php?88&1&C_Polaris_Div_2
# Failed on LL88, md 1, rundle ['D', 'Polaris', 1], url: https://www.learnedleague.com/match.php?88&1&D_Polaris_Div_1
# Failed on LL88, md 1, rundle ['D', 'Polaris', 2], url: https://www.learnedleague.com/match.php?88&1&D_Polaris_Div_2
# Failed on LL88, md 1, rundle ['E', 'Polaris', 1], url: https://www.learnedleague.com/match.php?88&1&E_Polaris_Div_1
# Failed on LL88, md 1, rundle ['E', 'Polaris', 2], url: https://www.learnedleague.com/match.php?88&1&E_Polaris_Div_2
# Failed on LL88, md 1, rundle ['R', 'Polaris', 0], url: https://www.learnedleague.com/match.php?88&1&R_Polaris
# Failed on LL88, md 1, rundle ['A', 'Prairie', 0], url: https://www.learnedleague.com/match.php?88&1&A_Prairie
# Failed on LL88, md 1, rundle ['B', 'Prairie', 0], url: https://www.learnedleague.com/match.php?88&1&B_Prairie
# Failed on LL88, md 1, rundle ['C', 'Prairie', 1], url: https://www.learnedleague.com/match.php?88&1&C_Prairie_Div_1
# Failed on LL88, md 1, rundle ['C', 'Prairie', 2], url: https://www.learnedleague.com/match.php?88&1&C_Prairie_Div_2
# Failed on LL88, md 1, rundle ['D', 'Prairie', 1], url: https://www.learnedleague.com/match.php?88&1&D_Prairie_Div_1
# Failed on LL88, md 1, rundle ['D', 'Prairie', 2], url: https://www.learnedleague.com/match.php?88&1&D_Prairie_Div_2
# Failed on LL88, md 1, rundle ['E', 'Prairie', 1], url: https://www.learnedleague.com/match.php?88&1&E_Prairie_Div_1
# Failed on LL88, md 1, rundle ['E', 'Prairie', 2], url: https://www.learnedleague.com/match.php?88&1&E_Prairie_Div_2
# Failed on LL88, md 1, rundle ['R', 'Prairie', 0], url: https://www.learnedleague.com/match.php?88&1&R_Prairie
# Failed on LL88, md 1, rundle ['A', 'Quarry', 0], url: https://www.learnedleague.com/match.php?88&1&A_Quarry
# Failed on LL88, md 1, rundle ['B', 'Quarry', 0], url: https://www.learnedleague.com/match.php?88&1&B_Quarry
# Failed on LL88, md 1, rundle ['C', 'Quarry', 1], url: https://www.learnedleague.com/match.php?88&1&C_Quarry_Div_1
# Failed on LL88, md 1, rundle ['C', 'Quarry', 2], url: https://www.learnedleague.com/match.php?88&1&C_Quarry_Div_2
# Failed on LL88, md 1, rundle ['D', 'Quarry', 1], url: https://www.learnedleague.com/match.php?88&1&D_Quarry_Div_1
# Failed on LL88, md 1, rundle ['D', 'Quarry', 2], url: https://www.learnedleague.com/match.php?88&1&D_Quarry_Div_2
# Failed on LL88, md 1, rundle ['E', 'Quarry', 1], url: https://www.learnedleague.com/match.php?88&1&E_Quarry_Div_1
# Failed on LL88, md 1, rundle ['E', 'Quarry', 2], url: https://www.learnedleague.com/match.php?88&1&E_Quarry_Div_2
# Failed on LL88, md 1, rundle ['R', 'Quarry', 0], url: https://www.learnedleague.com/match.php?88&1&R_Quarry
# Failed on LL88, md 1, rundle ['A', 'Rainforest', 0], url: https://www.learnedleague.com/match.php?88&1&A_Rainforest
# Failed on LL88, md 1, rundle ['B', 'Rainforest', 0], url: https://www.learnedleague.com/match.php?88&1&B_Rainforest
# Failed on LL88, md 1, rundle ['C', 'Rainforest', 1], url: https://www.learnedleague.com/match.php?88&1&C_Rainforest_Div_1
# Failed on LL88, md 1, rundle ['C', 'Rainforest', 2], url: https://www.learnedleague.com/match.php?88&1&C_Rainforest_Div_2
# Failed on LL88, md 1, rundle ['D', 'Rainforest', 1], url: https://www.learnedleague.com/match.php?88&1&D_Rainforest_Div_1
# Failed on LL88, md 1, rundle ['D', 'Rainforest', 2], url: https://www.learnedleague.com/match.php?88&1&D_Rainforest_Div_2
# Failed on LL88, md 1, rundle ['E', 'Rainforest', 1], url: https://www.learnedleague.com/match.php?88&1&E_Rainforest_Div_1
# Failed on LL88, md 1, rundle ['E', 'Rainforest', 2], url: https://www.learnedleague.com/match.php?88&1&E_Rainforest_Div_2
# Failed on LL88, md 1, rundle ['R', 'Rainforest', 0], url: https://www.learnedleague.com/match.php?88&1&R_Rainforest
# Failed on LL88, md 1, rundle ['A', 'Ravenna', 0], url: https://www.learnedleague.com/match.php?88&1&A_Ravenna
# Failed on LL88, md 1, rundle ['B', 'Ravenna', 0], url: https://www.learnedleague.com/match.php?88&1&B_Ravenna
# Failed on LL88, md 1, rundle ['C', 'Ravenna', 1], url: https://www.learnedleague.com/match.php?88&1&C_Ravenna_Div_1
# Failed on LL88, md 1, rundle ['C', 'Ravenna', 2], url: https://www.learnedleague.com/match.php?88&1&C_Ravenna_Div_2
# Failed on LL88, md 1, rundle ['D', 'Ravenna', 1], url: https://www.learnedleague.com/match.php?88&1&D_Ravenna_Div_1
# Failed on LL88, md 1, rundle ['D', 'Ravenna', 2], url: https://www.learnedleague.com/match.php?88&1&D_Ravenna_Div_2
# Failed on LL88, md 1, rundle ['E', 'Ravenna', 1], url: https://www.learnedleague.com/match.php?88&1&E_Ravenna_Div_1
# Failed on LL88, md 1, rundle ['E', 'Ravenna', 2], url: https://www.learnedleague.com/match.php?88&1&E_Ravenna_Div_2
# Failed on LL88, md 1, rundle ['R', 'Ravenna', 0], url: https://www.learnedleague.com/match.php?88&1&R_Ravenna
# Failed on LL88, md 1, rundle ['A', 'River', 0], url: https://www.learnedleague.com/match.php?88&1&A_River
# Failed on LL88, md 1, rundle ['B', 'River', 0], url: https://www.learnedleague.com/match.php?88&1&B_River
# Failed on LL88, md 1, rundle ['C', 'River', 1], url: https://www.learnedleague.com/match.php?88&1&C_River_Div_1
# Failed on LL88, md 1, rundle ['C', 'River', 2], url: https://www.learnedleague.com/match.php?88&1&C_River_Div_2
# Failed on LL88, md 1, rundle ['D', 'River', 1], url: https://www.learnedleague.com/match.php?88&1&D_River_Div_1
# Failed on LL88, md 1, rundle ['D', 'River', 2], url: https://www.learnedleague.com/match.php?88&1&D_River_Div_2
# Failed on LL88, md 1, rundle ['E', 'River', 1], url: https://www.learnedleague.com/match.php?88&1&E_River_Div_1
# Failed on LL88, md 1, rundle ['E', 'River', 2], url: https://www.learnedleague.com/match.php?88&1&E_River_Div_2
# Failed on LL88, md 1, rundle ['R', 'River', 0], url: https://www.learnedleague.com/match.php?88&1&R_River
# Failed on LL88, md 1, rundle ['A', 'Riviera', 0], url: https://www.learnedleague.com/match.php?88&1&A_Riviera
# Failed on LL88, md 1, rundle ['B', 'Riviera', 0], url: https://www.learnedleague.com/match.php?88&1&B_Riviera
# Failed on LL88, md 1, rundle ['C', 'Riviera', 1], url: https://www.learnedleague.com/match.php?88&1&C_Riviera_Div_1
# Failed on LL88, md 1, rundle ['C', 'Riviera', 2], url: https://www.learnedleague.com/match.php?88&1&C_Riviera_Div_2
# Failed on LL88, md 1, rundle ['D', 'Riviera', 1], url: https://www.learnedleague.com/match.php?88&1&D_Riviera_Div_1
# Failed on LL88, md 1, rundle ['D', 'Riviera', 2], url: https://www.learnedleague.com/match.php?88&1&D_Riviera_Div_2
# Failed on LL88, md 1, rundle ['E', 'Riviera', 1], url: https://www.learnedleague.com/match.php?88&1&E_Riviera_Div_1
# Failed on LL88, md 1, rundle ['E', 'Riviera', 2], url: https://www.learnedleague.com/match.php?88&1&E_Riviera_Div_2
# Failed on LL88, md 1, rundle ['R', 'Riviera', 0], url: https://www.learnedleague.com/match.php?88&1&R_Riviera
# Failed on LL88, md 1, rundle ['A', 'Rubicon', 0], url: https://www.learnedleague.com/match.php?88&1&A_Rubicon
# Failed on LL88, md 1, rundle ['B', 'Rubicon', 0], url: https://www.learnedleague.com/match.php?88&1&B_Rubicon
# Failed on LL88, md 1, rundle ['C', 'Rubicon', 1], url: https://www.learnedleague.com/match.php?88&1&C_Rubicon_Div_1
# Failed on LL88, md 1, rundle ['C', 'Rubicon', 2], url: https://www.learnedleague.com/match.php?88&1&C_Rubicon_Div_2
# Failed on LL88, md 1, rundle ['D', 'Rubicon', 1], url: https://www.learnedleague.com/match.php?88&1&D_Rubicon_Div_1
# Failed on LL88, md 1, rundle ['D', 'Rubicon', 2], url: https://www.learnedleague.com/match.php?88&1&D_Rubicon_Div_2
# Failed on LL88, md 1, rundle ['E', 'Rubicon', 1], url: https://www.learnedleague.com/match.php?88&1&E_Rubicon_Div_1
# Failed on LL88, md 1, rundle ['E', 'Rubicon', 2], url: https://www.learnedleague.com/match.php?88&1&E_Rubicon_Div_2
# Failed on LL88, md 1, rundle ['R', 'Rubicon', 0], url: https://www.learnedleague.com/match.php?88&1&R_Rubicon
# Failed on LL88, md 1, rundle ['A', 'Sakura', 0], url: https://www.learnedleague.com/match.php?88&1&A_Sakura
# Failed on LL88, md 1, rundle ['B', 'Sakura', 0], url: https://www.learnedleague.com/match.php?88&1&B_Sakura
# Failed on LL88, md 1, rundle ['C', 'Sakura', 1], url: https://www.learnedleague.com/match.php?88&1&C_Sakura_Div_1
# Failed on LL88, md 1, rundle ['C', 'Sakura', 2], url: https://www.learnedleague.com/match.php?88&1&C_Sakura_Div_2
# Failed on LL88, md 1, rundle ['D', 'Sakura', 1], url: https://www.learnedleague.com/match.php?88&1&D_Sakura_Div_1
# Failed on LL88, md 1, rundle ['D', 'Sakura', 2], url: https://www.learnedleague.com/match.php?88&1&D_Sakura_Div_2
# Failed on LL88, md 1, rundle ['E', 'Sakura', 1], url: https://www.learnedleague.com/match.php?88&1&E_Sakura_Div_1
# Failed on LL88, md 1, rundle ['E', 'Sakura', 2], url: https://www.learnedleague.com/match.php?88&1&E_Sakura_Div_2
# Failed on LL88, md 1, rundle ['R', 'Sakura', 0], url: https://www.learnedleague.com/match.php?88&1&R_Sakura
# Failed on LL88, md 1, rundle ['A', 'Savanna', 0], url: https://www.learnedleague.com/match.php?88&1&A_Savanna
# Failed on LL88, md 1, rundle ['B', 'Savanna', 0], url: https://www.learnedleague.com/match.php?88&1&B_Savanna
# Failed on LL88, md 1, rundle ['C', 'Savanna', 1], url: https://www.learnedleague.com/match.php?88&1&C_Savanna_Div_1
# Failed on LL88, md 1, rundle ['C', 'Savanna', 2], url: https://www.learnedleague.com/match.php?88&1&C_Savanna_Div_2
# Failed on LL88, md 1, rundle ['D', 'Savanna', 1], url: https://www.learnedleague.com/match.php?88&1&D_Savanna_Div_1
# Failed on LL88, md 1, rundle ['D', 'Savanna', 2], url: https://www.learnedleague.com/match.php?88&1&D_Savanna_Div_2
# Failed on LL88, md 1, rundle ['E', 'Savanna', 1], url: https://www.learnedleague.com/match.php?88&1&E_Savanna_Div_1
# Failed on LL88, md 1, rundle ['E', 'Savanna', 2], url: https://www.learnedleague.com/match.php?88&1&E_Savanna_Div_2
# Failed on LL88, md 1, rundle ['R', 'Savanna', 0], url: https://www.learnedleague.com/match.php?88&1&R_Savanna
# Failed on LL88, md 1, rundle ['A', 'Seaboard', 0], url: https://www.learnedleague.com/match.php?88&1&A_Seaboard
# Failed on LL88, md 1, rundle ['B', 'Seaboard', 0], url: https://www.learnedleague.com/match.php?88&1&B_Seaboard
# Failed on LL88, md 1, rundle ['C', 'Seaboard', 0], url: https://www.learnedleague.com/match.php?88&1&C_Seaboard
# Failed on LL88, md 1, rundle ['D', 'Seaboard', 1], url: https://www.learnedleague.com/match.php?88&1&D_Seaboard_Div_1
# Failed on LL88, md 1, rundle ['D', 'Seaboard', 2], url: https://www.learnedleague.com/match.php?88&1&D_Seaboard_Div_2
# Failed on LL88, md 1, rundle ['E', 'Seaboard', 1], url: https://www.learnedleague.com/match.php?88&1&E_Seaboard_Div_1
# Failed on LL88, md 1, rundle ['E', 'Seaboard', 2], url: https://www.learnedleague.com/match.php?88&1&E_Seaboard_Div_2
# Failed on LL88, md 1, rundle ['R', 'Seaboard', 0], url: https://www.learnedleague.com/match.php?88&1&R_Seaboard
# Failed on LL88, md 1, rundle ['A', 'Seneca', 0], url: https://www.learnedleague.com/match.php?88&1&A_Seneca
# Failed on LL88, md 1, rundle ['B', 'Seneca', 0], url: https://www.learnedleague.com/match.php?88&1&B_Seneca
# Failed on LL88, md 1, rundle ['C', 'Seneca', 1], url: https://www.learnedleague.com/match.php?88&1&C_Seneca_Div_1
# Failed on LL88, md 1, rundle ['C', 'Seneca', 2], url: https://www.learnedleague.com/match.php?88&1&C_Seneca_Div_2
# Failed on LL88, md 1, rundle ['D', 'Seneca', 1], url: https://www.learnedleague.com/match.php?88&1&D_Seneca_Div_1
# Failed on LL88, md 1, rundle ['D', 'Seneca', 2], url: https://www.learnedleague.com/match.php?88&1&D_Seneca_Div_2
# Failed on LL88, md 1, rundle ['E', 'Seneca', 1], url: https://www.learnedleague.com/match.php?88&1&E_Seneca_Div_1
# Failed on LL88, md 1, rundle ['E', 'Seneca', 2], url: https://www.learnedleague.com/match.php?88&1&E_Seneca_Div_2
# Failed on LL88, md 1, rundle ['R', 'Seneca', 1], url: https://www.learnedleague.com/match.php?88&1&R_Seneca_Div_1
# Failed on LL88, md 1, rundle ['R', 'Seneca', 2], url: https://www.learnedleague.com/match.php?88&1&R_Seneca_Div_2
# Failed on LL88, md 1, rundle ['A', 'Sequoia', 0], url: https://www.learnedleague.com/match.php?88&1&A_Sequoia
# Failed on LL88, md 1, rundle ['B', 'Sequoia', 0], url: https://www.learnedleague.com/match.php?88&1&B_Sequoia
# Failed on LL88, md 1, rundle ['C', 'Sequoia', 1], url: https://www.learnedleague.com/match.php?88&1&C_Sequoia_Div_1
# Failed on LL88, md 1, rundle ['C', 'Sequoia', 2], url: https://www.learnedleague.com/match.php?88&1&C_Sequoia_Div_2
# Failed on LL88, md 1, rundle ['D', 'Sequoia', 1], url: https://www.learnedleague.com/match.php?88&1&D_Sequoia_Div_1
# Failed on LL88, md 1, rundle ['D', 'Sequoia', 2], url: https://www.learnedleague.com/match.php?88&1&D_Sequoia_Div_2
# Failed on LL88, md 1, rundle ['D', 'Yukon', 1], url: https://www.learnedleague.com/match.php?88&1&D_Yukon_Div_1
# Failed on LL88, md 2, rundle ['C', 'Evergreen', 1], url: https://www.learnedleague.com/match.php?88&2&C_Evergreen_Div_1
# Failed on LL88, md 2, rundle ['B', 'Metro', 0], url: https://www.learnedleague.com/match.php?88&2&B_Metro
# Failed on LL88, md 2, rundle ['B', 'Riviera', 0], url: https://www.learnedleague.com/match.php?88&2&B_Riviera
# Failed on LL88, md 4, rundle ['R', 'Magnolia', 0], url: https://www.learnedleague.com/match.php?88&4&R_Magnolia
# Failed on LL88, md 4, rundle ['R', 'Prairie', 0], url: https://www.learnedleague.com/match.php?88&4&R_Prairie
# Failed on LL88, md 7, rundle ['C', 'Central', 1], url: https://www.learnedleague.com/match.php?88&7&C_Central_Div_1
# Failed on LL88, md 18, rundle ['B', 'Veldt', 0], url: https://www.learnedleague.com/match.php?88&18&B_Veldt
# Failed on LL88, md 20, rundle ['C', 'Metro', 1], url: https://www.learnedleague.com/match.php?88&20&C_Metro_Div_1
# completed LL88, total time: 6987.680282115936
# Failed on LL89, md 4, rundle ['D', 'Commonwealth', 2], url: https://www.learnedleague.com/match.php?89&4&D_Commonwealth_Div_2
# Failed on LL89, md 4, rundle ['E', 'Commonwealth', 1], url: https://www.learnedleague.com/match.php?89&4&E_Commonwealth_Div_1
# Failed on LL89, md 4, rundle ['E', 'Commonwealth', 2], url: https://www.learnedleague.com/match.php?89&4&E_Commonwealth_Div_2
# Failed on LL89, md 4, rundle ['R', 'Commonwealth', 0], url: https://www.learnedleague.com/match.php?89&4&R_Commonwealth
# Failed on LL89, md 4, rundle ['A', 'Continental', 0], url: https://www.learnedleague.com/match.php?89&4&A_Continental
# Failed on LL89, md 4, rundle ['B', 'Continental', 0], url: https://www.learnedleague.com/match.php?89&4&B_Continental
# Failed on LL89, md 4, rundle ['C', 'Continental', 1], url: https://www.learnedleague.com/match.php?89&4&C_Continental_Div_1
# completed LL89, total time: 7006.6363797187805
# Failed on LL90, md 14, rundle ['A', 'Mesa', 0], url: https://www.learnedleague.com/match.php?90&14&A_Mesa
# completed LL90, total time: 7081.487402915955
# completed LL91, total time: 7173.250543117523
# completed LL92, total time: 7364.847216844559
# Failed on LL93, md 3, rundle ['B', 'Highland', 0], url: https://www.learnedleague.com/match.php?93&3&B_Highland
# completed LL93, total time: 7457.494721889496
